# %% [markdown]
# ### Import data

# %%
import pandas as pd
from board_game_project.Data import DataSet

# %%
df = pd.read_csv('bgg.csv')

# %%
full_table, average_table, bayesian_table, wilson_table = DataSet(df).calculate_game_statistics()

# %%
full_table
# Out:
#                                                    title  Sum of rating score  \
# 0                                       !dentity Crisis?                52.60
# 1                                                #MyLife                40.00
# 2                                                &Cetera               226.50
# 3      '65: Squad-Level Combat in the Jungles of Vietnam               304.50
# 4      'CA' Tactical Naval Warfare in the Pacific, 19...               167.00
# ...                                                  ...                  ...
# 23259                                   なつめも (Natsumemo)               142.50
# 23260                                    ひとひら (Hitohira)                74.00
# 23261                   カマクラコレクション (Kamakura Collection)                30.00
# 23262                                  ボブジテン (Bob Jiten)                44.00
# 23263                                   猿道 (Monkey Road)                52.06
#
# ...

# %%
bayesian_table
# Out:
#                        title  Number of votes  Bayesian Average rating score
# 0        Dungeon Universalis               79                       8.681246
# 1                TerroriXico               43                       8.352623
# 2                 Core Space               76                       8.279899
# 3                    Skytear               69                       8.254334
# 4             Goblin Grapple               88                       8.173812
# ...                      ...              ...                            ...
# 23259                  Bunco               74                       3.519510
# 23260     Chutes and Ladders               84                       3.512471
# 23261            Tic-Tac-Toe               90                       3.474635
# 23262             The Ungame               83                       3.236259
# 23263  Alien: USCSS Nostromo               59                       2.769390
#
# [23264 rows x 3 columns]

# %%
average_table
# Out:
#                                     title  Number of votes  \
# 0                                 Zamitar                1
# 1                                    Junk                2
# 2         David Dickinson's Antique Chase                1
# 3                          Baseball Mania                1
# 4                        Medieval Warfare                1
# ...                                   ...              ...
# 23259                            Piratack                2
# 23260  Barbary Coast War (Second Edition)                4
# 23261              Don't Point the Finger                2
# 23262                     Kratz Die Kurve                1
# 23263                      Tops and Tails                2
#
#        Average rating score
# 0                      10.0
# 1                      10.0
# 2                      10.0
# 3                      10.0
# 4                      10.0
# ...                     ...
# 23259                   1.0
# ...

# %%
wilson_table
# Out:
#                                    title  Number of votes  Wilson lower bound
# 0                    Dungeon Universalis               79            9.241275
# 1                            TerroriXico               43            9.156861
# 2                                Skytear               69            8.735694
# 3                             Core Space               76            8.727555
# 4      World At War 85: Storming the Gap               47            8.676398
# ...                                  ...              ...                 ...
# 23259                           Tri-Umph                1            0.206549
# 23260                    Kratz Die Kurve                1            0.206549
# 23261                                Öko                1            0.206549
# 23262                        Jassin 1915                1            0.206549
# 23263                            Beeline                1            0.206549
#
# [23264 rows x 3 columns]

# %% [markdown]
# ### Data visualization

# %%
from board_game_project.Data_Visualization import DataVisualization

# %%
title = full_table['title']
x = full_table['Number of votes']
y = full_table['Average rating score']
z = full_table['Bayesian Average rating score']
k = full_table['Wilson lower bound']

# %%
viz = DataVisualization(title, x,y,z,k)
viz.plot_bayesian_ranking()
viz.plot_average_ranking()
viz.plot_wilson_lower_bound()
# Out:
# Variance of Bayesian average scores: 0.23113583831747822
# Variance of Average scores: 1.5010161231898016
# Variance of Wilson scores: 2.3120714621408514

# %%
viz.plot_boxplot()

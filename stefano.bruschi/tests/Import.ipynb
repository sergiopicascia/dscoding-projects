# %% [markdown]
# ## IMPORT DATA

# %%
offset = 0
limit = 3000
period = '10y' # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max

# %%
import pandas as pd

data = pd.read_csv("http://www.nasdaqtrader.com/dynamic/SymDir/nasdaqtraded.txt", sep='|')
data_clean = data[data['Test Issue'] == 'N']
symbols = data_clean['NASDAQ Symbol'].tolist()
print('total number of symbols traded = {}'.format(len(symbols)))
# Out:
# total number of symbols traded = 11207

# %%
import yfinance as yf
import os, contextlib

# %%
# %%time

limit = limit if limit else len(symbols)
end = min(offset + limit, len(symbols))
is_valid = [False] * len(symbols)
# force silencing of verbose API
with open(os.devnull, 'w') as devnull:
    with contextlib.redirect_stdout(devnull):
        for i in range(offset, end):
            s = symbols[i]
            data = yf.download(s, period=period)
            if len(data.index) == 0:
                continue
        
            is_valid[i] = True
            data.to_csv('Data/{}.csv'.format(s))

print('Total number of valid symbols downloaded = {}'.format(sum(is_valid)))
# Out:
# 1 Failed download:
# ['AACT=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AACT+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AAIC-B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AAIC-C']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ABR-D']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ABR-E']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ABR-F']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ACHR+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ACP-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ACR-C']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ACR-D']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ACRO=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ACRO+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ADC-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ADEX=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ADEX+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ADRT=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AEL-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AEL-B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AEON+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AEVA+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AGM-C']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AGM-D']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AGM-E']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AGM-F']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AGM-G']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AGM.A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AHH-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AHL-C']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AHL-D']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AHL-E']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AHT-D']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AHT-F']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AHT-G']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AHT-H']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AHT-I']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AIG-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AKO.A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AKO.B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AL-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ALL-B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ALL-H']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ALL-I']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ALL-J']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ALTG-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ALUR+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AMBI+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AMBP+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AMH-G']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AMH-H']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AMPX+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AP+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['APCA=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['APCA+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['APGB=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['APGB+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['APO-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ARGO-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ARR-C']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ASB-E']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ASB-F']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ATCO-D']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ATCO-H']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ATEK=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ATEK+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ATH-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ATH-B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ATH-C']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ATH-D']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['ATH-E']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AUB-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AULT-D']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['AXON']: Exception('%ticker%: No price data found, symbol may be delisted (period=10y)')
#
# 1 Failed download:
# ['AXS']: Exception('%ticker%: No price data found, symbol may be delisted (period=10y)')
#
# 1 Failed download:
# ['AXS-E']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-E']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-K']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-L']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-M']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-N']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-O']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-P']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-Q']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-S']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BARK+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BBAI+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BC-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BC-B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BC-C']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BEP-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BF.A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BF.B']: Exception('%ticker%: No price data found, symbol may be delisted (period=10y)')
#
# 1 Failed download:
# ['BFAC=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BFAC+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BFLY+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BFS-D']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BFS-E']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BH.A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BHIL+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BHR-B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BHR-D']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BIO.B']: Exception('%ticker%: No price data found, symbol may be delisted (period=10y)')
#
# 1 Failed download:
# ['BIP-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BIP-B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BITE=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BITE+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BKKT+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BKSY+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BLUA=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BLUA+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BMAC=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BMAC+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BML-G']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BML-H']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BML-J']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BML-L']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BMTX+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BNRE.A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BOH-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BRD=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BRD+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BRK.A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BRK.B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BURU+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BW-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BYN=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['BYN+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['C-J']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['C-N']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CADE-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CCVI=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CCVI+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CDR-B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CDR-C']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CELG^']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CFG-D']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CFG-E']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CFR-B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CHMI-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CHMI-B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CIG.C']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CIM-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CIM-B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CIM-C']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CIM-D']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CIO-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CLBR=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CLDI+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CLDT-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CLVT-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CMRE-B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CMRE-C']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CMRE-D']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CMRE-E']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CMS-B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CMS-C']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CNDA=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CNDA+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CNDB=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CNDB+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CNO-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CODI-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CODI-B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CODI-C']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['COF-I']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['COF-J']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['COF-K']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['COF-L']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['COF-N']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CORR-A']: Exception('%ticker%: No data found, symbol may be delisted')
# Failed to get ticker 'CPTK=' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
#
# 1 Failed download:
# ['CPTK=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CRD.A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CRD.B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CSR-C']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CSTA=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CSTA+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CTA-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CTA-B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CTO-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CTOS+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CTV+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CUBI-E']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CUBI-F']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CVE+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CVII=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CVII+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['CWEN.A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['DBRG-H']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['DBRG-I']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['DBRG-J']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['DC+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['DLNG-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['DLNG-B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['DLR-J']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['DLR-K']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['DLR-L']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['DMYY=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['DMYY+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['DNA+']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['DRH-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['DSAQ=']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['DSX-B']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['DUK-A']: Exception('%ticker%: No data found, symbol may be delisted')
#
# 1 Failed download:
# ['DX-C']: Exception('%ticker%: No data found, symbol may be delisted')
# Total number of valid symbols downloaded = 2795
# CPU times: total: 47min 48s
# Wall time: 1h 29min 16s

# %%
valid_data = data_clean[is_valid]
valid_data.to_csv('symbols_valid_meta.csv', index=False)

# %%
etfs = valid_data[valid_data['ETF'] == 'Y']['NASDAQ Symbol'].tolist()
stocks = valid_data[valid_data['ETF'] == 'N']['NASDAQ Symbol'].tolist()

# %%
import shutil
from os.path import isfile, join

def move_symbols(symbols, dest):
    for s in symbols:
        filename = '{}.csv'.format(s)
        shutil.move(join('Data', filename), join(dest, filename))
        
move_symbols(etfs, "Data/etfs")
move_symbols(stocks, "Data/stocks")

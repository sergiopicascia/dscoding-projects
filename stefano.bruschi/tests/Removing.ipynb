# %%
import os
import pandas as pd

folder_path = 'Data'

# Loop attraverso tutti i file nella cartella
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)

        # Leggi il file CSV
        df = pd.read_csv(file_path)

        # Rimuovi la colonna 'monthly_mean' se presente
        if 'Vol_month_mean' in df.columns:
            df = df.drop('Vol_month_mean', axis=1)

            # Salva il DataFrame modificato nel file
            df.to_csv(file_path, index=False)
            print(f"Colonna 'monthly_mean' rimossa da {filename}")
        else:
            print(f"Colonna 'monthly_mean' non presente in {filename}")
# Out:
# Colonna 'monthly_mean' rimossa da AAA.csv
# Colonna 'monthly_mean' rimossa da AAAU.csv
# Colonna 'monthly_mean' rimossa da AADR.csv
# Colonna 'monthly_mean' rimossa da AAPB.csv
# Colonna 'monthly_mean' rimossa da AAPD.csv
# Colonna 'monthly_mean' rimossa da AAPU.csv
# Colonna 'monthly_mean' rimossa da AAPY.csv
# Colonna 'monthly_mean' rimossa da AAXJ.csv
# Colonna 'monthly_mean' rimossa da ABEQ.csv
# Colonna 'monthly_mean' rimossa da ACES.csv
# Colonna 'monthly_mean' rimossa da ACIO.csv
# Colonna 'monthly_mean' rimossa da ACSI.csv
# Colonna 'monthly_mean' rimossa da ACTV.csv
# Colonna 'monthly_mean' rimossa da ACVF.csv
# Colonna 'monthly_mean' rimossa da ACWI.csv
# Colonna 'monthly_mean' rimossa da ACWV.csv
# Colonna 'monthly_mean' rimossa da ACWX.csv
# Colonna 'monthly_mean' rimossa da ADFI.csv
# Colonna 'monthly_mean' rimossa da ADIV.csv
# Colonna 'monthly_mean' rimossa da ADME.csv
# Colonna 'monthly_mean' rimossa da ADPV.csv
# Colonna 'monthly_mean' rimossa da ADVE.csv
# Colonna 'monthly_mean' rimossa da AEMB.csv
# Colonna 'monthly_mean' rimossa da AESR.csv
# Colonna 'monthly_mean' rimossa da AETH.csv
# Colonna 'monthly_mean' rimossa da AFIF.csv
# Colonna 'monthly_mean' rimossa da AFK.csv
# Colonna 'monthly_mean' rimossa da AFLG.csv
# Colonna 'monthly_mean' rimossa da AFMC.csv
# Colonna 'monthly_mean' rimossa da AFSM.csv
# Colonna 'monthly_mean' rimossa da AFTY.csv
# Colonna 'monthly_mean' rimossa da AGG.csv
# Colonna 'monthly_mean' rimossa da AGGH.csv
# Colonna 'monthly_mean' rimossa da AGGY.csv
# Colonna 'monthly_mean' rimossa da AGIH.csv
# Colonna 'monthly_mean' rimossa da AGNG.csv
# Colonna 'monthly_mean' rimossa da AGOX.csv
# Colonna 'monthly_mean' rimossa da AGQ.csv
# Colonna 'monthly_mean' rimossa da AGQI.csv
# Colonna 'monthly_mean' rimossa da AGRH.csv
# Colonna 'monthly_mean' rimossa da AGZ.csv
# Colonna 'monthly_mean' rimossa da AGZD.csv
# Colonna 'monthly_mean' rimossa da AHLT.csv
# Colonna 'monthly_mean' rimossa da AHOY.csv
# Colonna 'monthly_mean' rimossa da AHYB.csv
# Colonna 'monthly_mean' rimossa da AIA.csv
# Colonna 'monthly_mean' rimossa da AIDB.csv
# Colonna 'monthly_mean' rimossa da AIEQ.csv
# Colonna 'monthly_mean' rimossa da AIQ.csv
# Colonna 'monthly_mean' rimossa da AIRR.csv
# Colonna 'monthly_mean' rimossa da AIVI.csv
# Colonna 'monthly_mean' rimossa da AIVL.csv
# Colonna 'monthly_mean' rimossa da ALTL.csv
# Colonna 'monthly_mean' rimossa da ALTY.csv
# Colonna 'monthly_mean' rimossa da ALUM.csv
# Colonna 'monthly_mean' rimossa da AMAX.csv
# Colonna 'monthly_mean' rimossa da AMDS.csv
# Colonna 'monthly_mean' rimossa da AMDY.csv
# Colonna 'monthly_mean' rimossa da AMID.csv
# Colonna 'monthly_mean' rimossa da AMLP.csv
# Colonna 'monthly_mean' rimossa da AMNA.csv
# Colonna 'monthly_mean' rimossa da AMND.csv
# Colonna 'monthly_mean' rimossa da AMOM.csv
# Colonna 'monthly_mean' rimossa da AMPD.csv
# Colonna 'monthly_mean' rimossa da AMZA.csv
# Colonna 'monthly_mean' rimossa da AMZD.csv
# Colonna 'monthly_mean' rimossa da AMZP.csv
# Colonna 'monthly_mean' rimossa da AMZU.csv
# Colonna 'monthly_mean' rimossa da AMZY.csv
# Colonna 'monthly_mean' rimossa da ANEW.csv
# Colonna 'monthly_mean' rimossa da ANGL.csv
# Colonna 'monthly_mean' rimossa da AOA.csv
# Colonna 'monthly_mean' rimossa da AOK.csv
# Colonna 'monthly_mean' rimossa da AOM.csv
# Colonna 'monthly_mean' rimossa da AOR.csv
# Colonna 'monthly_mean' rimossa da AOTG.csv
# Colonna 'monthly_mean' rimossa da APCB.csv
# Colonna 'monthly_mean' rimossa da APIE.csv
# Colonna 'monthly_mean' rimossa da APLY.csv
# Colonna 'monthly_mean' rimossa da APMU.csv
# Colonna 'monthly_mean' rimossa da APRD.csv
# Colonna 'monthly_mean' rimossa da APRH.csv
# Colonna 'monthly_mean' rimossa da APRJ.csv
# Colonna 'monthly_mean' rimossa da APRQ.csv
# Colonna 'monthly_mean' rimossa da APRT.csv
# Colonna 'monthly_mean' rimossa da APRW.csv
# Colonna 'monthly_mean' rimossa da APRZ.csv
# Colonna 'monthly_mean' rimossa da APUE.csv
# Colonna 'monthly_mean' rimossa da AQWA.csv
# Colonna 'monthly_mean' rimossa da ARB.csv
# Colonna 'monthly_mean' rimossa da ARCM.csv
# Colonna 'monthly_mean' rimossa da ARGT.csv
# Colonna 'monthly_mean' rimossa da ARKA.csv
# Colonna 'monthly_mean' rimossa da ARKC.csv
# Colonna 'monthly_mean' rimossa da ARKD.csv
# Colonna 'monthly_mean' rimossa da ARKF.csv
# Colonna 'monthly_mean' rimossa da ARKG.csv
# Colonna 'monthly_mean' rimossa da ARKK.csv
# Colonna 'monthly_mean' rimossa da ARKQ.csv
# Colonna 'monthly_mean' rimossa da ARKW.csv
# Colonna 'monthly_mean' rimossa da ARKX.csv
# Colonna 'monthly_mean' rimossa da ARKY.csv
# Colonna 'monthly_mean' rimossa da ARKZ.csv
# Colonna 'monthly_mean' rimossa da ARMR.csv
# Colonna 'monthly_mean' rimossa da ARP.csv
# Colonna 'monthly_mean' rimossa da ARVR.csv
# Colonna 'monthly_mean' rimossa da ASEA.csv
# Colonna 'monthly_mean' rimossa da ASET.csv
# Colonna 'monthly_mean' rimossa da ASHR.csv
# Colonna 'monthly_mean' rimossa da ASHS.csv
# Colonna 'monthly_mean' rimossa da ASHX.csv
# Colonna 'monthly_mean' rimossa da ASIA.csv
# Colonna 'monthly_mean' rimossa da ATFV.csv
# Colonna 'monthly_mean' rimossa da AUGT.csv
# Colonna 'monthly_mean' rimossa da AUGW.csv
# Colonna 'monthly_mean' rimossa da AUGZ.csv
# Colonna 'monthly_mean' rimossa da AUSF.csv
# Colonna 'monthly_mean' rimossa da AVDE.csv
# Colonna 'monthly_mean' rimossa da AVDS.csv
# Colonna 'monthly_mean' rimossa da AVDV.csv
# Colonna 'monthly_mean' rimossa da AVEE.csv
# Colonna 'monthly_mean' rimossa da AVEM.csv
# Colonna 'monthly_mean' rimossa da AVES.csv
# Colonna 'monthly_mean' rimossa da AVGE.csv
# Colonna 'monthly_mean' rimossa da AVGV.csv
# Colonna 'monthly_mean' rimossa da AVIE.csv
# Colonna 'monthly_mean' rimossa da AVIG.csv
# Colonna 'monthly_mean' rimossa da AVIV.csv
# Colonna 'monthly_mean' rimossa da AVLC.csv
# Colonna 'monthly_mean' rimossa da AVLV.csv
# Colonna 'monthly_mean' rimossa da AVMA.csv
# Colonna 'monthly_mean' rimossa da AVMC.csv
# Colonna 'monthly_mean' rimossa da AVMU.csv
# Colonna 'monthly_mean' rimossa da AVMV.csv
# Colonna 'monthly_mean' rimossa da AVNM.csv
# Colonna 'monthly_mean' rimossa da AVNV.csv
# Colonna 'monthly_mean' rimossa da AVRE.csv
# Colonna 'monthly_mean' rimossa da AVSC.csv
# Colonna 'monthly_mean' rimossa da AVSD.csv
# Colonna 'monthly_mean' rimossa da AVSE.csv
# Colonna 'monthly_mean' rimossa da AVSF.csv
# Colonna 'monthly_mean' rimossa da AVSU.csv
# Colonna 'monthly_mean' rimossa da AVUS.csv
# Colonna 'monthly_mean' rimossa da AVUV.csv
# Colonna 'monthly_mean' rimossa da AWAY.csv
# Colonna 'monthly_mean' rimossa da AWEG.csv
# Colonna 'monthly_mean' rimossa da AZTD.csv
# Colonna 'monthly_mean' rimossa da BAB.csv
# Colonna 'monthly_mean' rimossa da BABX.csv
# Colonna 'monthly_mean' rimossa da BAD.csv
# Colonna 'monthly_mean' rimossa da BALI.csv
# Colonna 'monthly_mean' rimossa da BALT.csv
# Colonna 'monthly_mean' rimossa da BAMA.csv
# Colonna 'monthly_mean' rimossa da BAMB.csv
# Colonna 'monthly_mean' rimossa da BAMD.csv
# Colonna 'monthly_mean' rimossa da BAMG.csv
# Colonna 'monthly_mean' rimossa da BAMO.csv
# Colonna 'monthly_mean' rimossa da BAMU.csv
# Colonna 'monthly_mean' rimossa da BAMV.csv
# Colonna 'monthly_mean' rimossa da BAMY.csv
# Colonna 'monthly_mean' rimossa da BAPR.csv
# Colonna 'monthly_mean' rimossa da BATT.csv
# Colonna 'monthly_mean' rimossa da BAUG.csv
# Colonna 'monthly_mean' rimossa da BBAG.csv
# Colonna 'monthly_mean' rimossa da BBAX.csv
# Colonna 'monthly_mean' rimossa da BBC.csv
# Colonna 'monthly_mean' rimossa da BBCA.csv
# Colonna 'monthly_mean' rimossa da BBCB.csv
# Colonna 'monthly_mean' rimossa da BBEM.csv
# Colonna 'monthly_mean' rimossa da BBEU.csv
# Colonna 'monthly_mean' rimossa da BBH.csv
# Colonna 'monthly_mean' rimossa da BBHY.csv
# Colonna 'monthly_mean' rimossa da BBIB.csv
# Colonna 'monthly_mean' rimossa da BBIN.csv
# Colonna 'monthly_mean' rimossa da BBIP.csv
# Colonna 'monthly_mean' rimossa da BBJP.csv
# Colonna 'monthly_mean' rimossa da BBLB.csv
# Colonna 'monthly_mean' rimossa da BBLU.csv
# Colonna 'monthly_mean' rimossa da BBMC.csv
# Colonna 'monthly_mean' rimossa da BBP.csv
# Colonna 'monthly_mean' rimossa da BBRE.csv
# Colonna 'monthly_mean' rimossa da BBSA.csv
# Colonna 'monthly_mean' rimossa da BBSB.csv
# Colonna 'monthly_mean' rimossa da BBSC.csv
# Colonna 'monthly_mean' rimossa da BBUS.csv
# Colonna 'monthly_mean' rimossa da BCD.csv
# Colonna 'monthly_mean' rimossa da BCDF.csv
# Colonna 'monthly_mean' rimossa da BCHP.csv
# Colonna 'monthly_mean' rimossa da BCI.csv
# Colonna 'monthly_mean' rimossa da BCIM.csv
# Colonna 'monthly_mean' rimossa da BDCX.csv
# Colonna 'monthly_mean' rimossa da BDEC.csv
# Colonna 'monthly_mean' rimossa da BDGS.csv
# Colonna 'monthly_mean' rimossa da BDRY.csv
# Colonna 'monthly_mean' rimossa da BDVG.csv
# Colonna 'monthly_mean' rimossa da BECO.csv
# Colonna 'monthly_mean' rimossa da BEDZ.csv
# Colonna 'monthly_mean' rimossa da BEEZ.csv
# Colonna 'monthly_mean' rimossa da BEMB.csv
# Colonna 'monthly_mean' rimossa da BERZ.csv
# Colonna 'monthly_mean' rimossa da BETE.csv
# Colonna 'monthly_mean' rimossa da BETH.csv
# Colonna 'monthly_mean' rimossa da BETZ.csv
# Colonna 'monthly_mean' rimossa da BFEB.csv
# Colonna 'monthly_mean' rimossa da BFIT.csv
# Colonna 'monthly_mean' rimossa da BFIX.csv
# Colonna 'monthly_mean' rimossa da BFOR.csv
# Colonna 'monthly_mean' rimossa da BGIG.csv
# Colonna 'monthly_mean' rimossa da BGLD.csv
# Colonna 'monthly_mean' rimossa da BGRN.csv
# Colonna 'monthly_mean' rimossa da BHYB.csv
# Colonna 'monthly_mean' rimossa da BIB.csv
# Colonna 'monthly_mean' rimossa da BIBL.csv
# Colonna 'monthly_mean' rimossa da BIGB.csv
# Colonna 'monthly_mean' rimossa da BIL.csv
# Colonna 'monthly_mean' rimossa da BILS.csv
# Colonna 'monthly_mean' rimossa da BILZ.csv
# Colonna 'monthly_mean' rimossa da BINC.csv
# Colonna 'monthly_mean' rimossa da BINV.csv
# Colonna 'monthly_mean' rimossa da BIS.csv
# Colonna 'monthly_mean' rimossa da BITC.csv
# Colonna 'monthly_mean' rimossa da BITI.csv
# Colonna 'monthly_mean' rimossa da BITO.csv
# Colonna 'monthly_mean' rimossa da BITQ.csv
# Colonna 'monthly_mean' rimossa da BITS.csv
# Colonna 'monthly_mean' rimossa da BITX.csv
# Colonna 'monthly_mean' rimossa da BIV.csv
# Colonna 'monthly_mean' rimossa da BIZD.csv
# Colonna 'monthly_mean' rimossa da BJAN.csv
# Colonna 'monthly_mean' rimossa da BJK.csv
# Colonna 'monthly_mean' rimossa da BJUL.csv
# Colonna 'monthly_mean' rimossa da BJUN.csv
# Colonna 'monthly_mean' rimossa da BKAG.csv
# Colonna 'monthly_mean' rimossa da BKCH.csv
# Colonna 'monthly_mean' rimossa da BKCI.csv
# Colonna 'monthly_mean' rimossa da BKEM.csv
# Colonna 'monthly_mean' rimossa da BKES.csv
# Colonna 'monthly_mean' rimossa da BKF.csv
# Colonna 'monthly_mean' rimossa da BKGI.csv
# Colonna 'monthly_mean' rimossa da BKHY.csv
# Colonna 'monthly_mean' rimossa da BKIE.csv
# Colonna 'monthly_mean' rimossa da BKIS.csv
# Colonna 'monthly_mean' rimossa da BKIV.csv
# Colonna 'monthly_mean' rimossa da BKLC.csv
# Colonna 'monthly_mean' rimossa da BKLN.csv
# Colonna 'monthly_mean' rimossa da BKMC.csv
# Colonna 'monthly_mean' rimossa da BKSE.csv
# Colonna 'monthly_mean' rimossa da BKUI.csv
# Colonna 'monthly_mean' rimossa da BKUS.csv
# Colonna 'monthly_mean' rimossa da BKWO.csv
# Colonna 'monthly_mean' rimossa da BLCN.csv
# Colonna 'monthly_mean' rimossa da BLCR.csv
# Colonna 'monthly_mean' rimossa da BLCV.csv
# Colonna 'monthly_mean' rimossa da BLDG.csv
# Colonna 'monthly_mean' rimossa da BLES.csv
# Colonna 'monthly_mean' rimossa da BLHY.csv
# Colonna 'monthly_mean' rimossa da BLKC.csv
# Colonna 'monthly_mean' rimossa da BLLD.csv
# Colonna 'monthly_mean' rimossa da BLOK.csv
# Colonna 'monthly_mean' rimossa da BLV.csv
# Colonna 'monthly_mean' rimossa da BMAR.csv
# Colonna 'monthly_mean' rimossa da BMAY.csv
# Colonna 'monthly_mean' rimossa da BMED.csv
# Colonna 'monthly_mean' rimossa da BMVP.csv
# Colonna 'monthly_mean' rimossa da BND.csv
# Colonna 'monthly_mean' rimossa da BNDC.csv
# Colonna 'monthly_mean' rimossa da BNDD.csv
# Colonna 'monthly_mean' rimossa da BNDI.csv
# Colonna 'monthly_mean' rimossa da BNDW.csv
# Colonna 'monthly_mean' rimossa da BNDX.csv
# Colonna 'monthly_mean' rimossa da BNE.csv
# Colonna 'monthly_mean' rimossa da BNGE.csv
# Colonna 'monthly_mean' rimossa da BNO.csv
# Colonna 'monthly_mean' rimossa da BNOV.csv
# Colonna 'monthly_mean' rimossa da BOAT.csv
# Colonna 'monthly_mean' rimossa da BOCT.csv
# Colonna 'monthly_mean' rimossa da BOIL.csv
# Colonna 'monthly_mean' rimossa da BOND.csv
# Colonna 'monthly_mean' rimossa da BOTZ.csv
# Colonna 'monthly_mean' rimossa da BOUT.csv
# Colonna 'monthly_mean' rimossa da BOXX.csv
# Colonna 'monthly_mean' rimossa da BPAY.csv
# Colonna 'monthly_mean' rimossa da BRAZ.csv
# Colonna 'monthly_mean' rimossa da BRF.csv
# Colonna 'monthly_mean' rimossa da BRLN.csv
# Colonna 'monthly_mean' rimossa da BRNY.csv
# Colonna 'monthly_mean' rimossa da BRZU.csv
# Colonna 'monthly_mean' rimossa da BSCN.csv
# Colonna 'monthly_mean' rimossa da BSCO.csv
# Colonna 'monthly_mean' rimossa da BSCP.csv
# Colonna 'monthly_mean' rimossa da BSCQ.csv
# Colonna 'monthly_mean' rimossa da BSCR.csv
# Colonna 'monthly_mean' rimossa da BSCS.csv
# Colonna 'monthly_mean' rimossa da BSCT.csv
# Colonna 'monthly_mean' rimossa da BSCU.csv
# Colonna 'monthly_mean' rimossa da BSCV.csv
# Colonna 'monthly_mean' rimossa da BSCW.csv
# Colonna 'monthly_mean' rimossa da BSCX.csv
# Colonna 'monthly_mean' rimossa da BSEP.csv
# Colonna 'monthly_mean' rimossa da BSJN.csv
# Colonna 'monthly_mean' rimossa da BSJO.csv
# Colonna 'monthly_mean' rimossa da BSJP.csv
# Colonna 'monthly_mean' rimossa da BSJQ.csv
# Colonna 'monthly_mean' rimossa da BSJR.csv
# Colonna 'monthly_mean' rimossa da BSJS.csv
# Colonna 'monthly_mean' rimossa da BSJT.csv
# Colonna 'monthly_mean' rimossa da BSJU.csv
# Colonna 'monthly_mean' rimossa da BSJV.csv
# Colonna 'monthly_mean' rimossa da BSMC.csv
# Colonna 'monthly_mean' rimossa da BSMN.csv
# Colonna 'monthly_mean' rimossa da BSMO.csv
# Colonna 'monthly_mean' rimossa da BSMP.csv
# Colonna 'monthly_mean' rimossa da BSMQ.csv
# Colonna 'monthly_mean' rimossa da BSMR.csv
# Colonna 'monthly_mean' rimossa da BSMS.csv
# Colonna 'monthly_mean' rimossa da BSMT.csv
# Colonna 'monthly_mean' rimossa da BSMU.csv
# Colonna 'monthly_mean' rimossa da BSMV.csv
# Colonna 'monthly_mean' rimossa da BSMW.csv
# Colonna 'monthly_mean' rimossa da BSR.csv
# Colonna 'monthly_mean' rimossa da BSSX.csv
# Colonna 'monthly_mean' rimossa da BSTP.csv
# Colonna 'monthly_mean' rimossa da BSV.csv
# Colonna 'monthly_mean' rimossa da BSVO.csv
# Colonna 'monthly_mean' rimossa da BTAL.csv
# Colonna 'monthly_mean' rimossa da BTEC.csv
# Colonna 'monthly_mean' rimossa da BTEK.csv
# Colonna 'monthly_mean' rimossa da BTF.csv
# Colonna 'monthly_mean' rimossa da BTHM.csv
# Colonna 'monthly_mean' rimossa da BTOP.csv
# Colonna 'monthly_mean' rimossa da BTR.csv
# Colonna 'monthly_mean' rimossa da BUCK.csv
# Colonna 'monthly_mean' rimossa da BUFB.csv
# Colonna 'monthly_mean' rimossa da BUFD.csv
# Colonna 'monthly_mean' rimossa da BUFF.csv
# Colonna 'monthly_mean' rimossa da BUFG.csv
# Colonna 'monthly_mean' rimossa da BUFQ.csv
# Colonna 'monthly_mean' rimossa da BUFR.csv
# Colonna 'monthly_mean' rimossa da BUFT.csv
# Colonna 'monthly_mean' rimossa da BUFZ.csv
# Colonna 'monthly_mean' rimossa da BUG.csv
# Colonna 'monthly_mean' rimossa da BUL.csv
# Colonna 'monthly_mean' rimossa da BULD.csv
# Colonna 'monthly_mean' rimossa da BULZ.csv
# Colonna 'monthly_mean' rimossa da BUSA.csv
# Colonna 'monthly_mean' rimossa da BUXX.csv
# Colonna 'monthly_mean' rimossa da BUYW.csv
# Colonna 'monthly_mean' rimossa da BUYZ.csv
# Colonna 'monthly_mean' rimossa da BUZZ.csv
# Colonna 'monthly_mean' rimossa da BWEB.csv
# Colonna 'monthly_mean' rimossa da BWET.csv
# Colonna 'monthly_mean' rimossa da BWTG.csv
# Colonna 'monthly_mean' rimossa da BWX.csv
# Colonna 'monthly_mean' rimossa da BWZ.csv
# Colonna 'monthly_mean' rimossa da BYLD.csv
# Colonna 'monthly_mean' rimossa da BYOB.csv
# Colonna 'monthly_mean' rimossa da BYRE.csv
# Colonna 'monthly_mean' rimossa da BYTE.csv
# Colonna 'monthly_mean' rimossa da BZQ.csv
# Colonna 'monthly_mean' rimossa da CACG.csv
# Colonna 'monthly_mean' rimossa da CAFG.csv
# Colonna 'monthly_mean' rimossa da CALF.csv
# Colonna 'monthly_mean' rimossa da CALY.csv
# Colonna 'monthly_mean' rimossa da CAML.csv
# Colonna 'monthly_mean' rimossa da CAMX.csv
# Colonna 'monthly_mean' rimossa da CANC.csv
# Colonna 'monthly_mean' rimossa da CANE.csv
# Colonna 'monthly_mean' rimossa da CAOS.csv
# Colonna 'monthly_mean' rimossa da CAPE.csv
# Colonna 'monthly_mean' rimossa da CARD.csv
# Colonna 'monthly_mean' rimossa da CARU.csv
# Colonna 'monthly_mean' rimossa da CARY.csv
# Colonna 'monthly_mean' rimossa da CARZ.csv
# Colonna 'monthly_mean' rimossa da CATH.csv
# Colonna 'monthly_mean' rimossa da CBLS.csv
# Colonna 'monthly_mean' rimossa da CBON.csv
# Colonna 'monthly_mean' rimossa da CBSE.csv
# Colonna 'monthly_mean' rimossa da CCOR.csv
# Colonna 'monthly_mean' rimossa da CCRV.csv
# Colonna 'monthly_mean' rimossa da CCSO.csv
# Colonna 'monthly_mean' rimossa da CDC.csv
# Colonna 'monthly_mean' rimossa da CDEI.csv
# Colonna 'monthly_mean' rimossa da CDL.csv
# Colonna 'monthly_mean' rimossa da CDX.csv
# Colonna 'monthly_mean' rimossa da CEF.csv
# Colonna 'monthly_mean' rimossa da CEFA.csv
# Colonna 'monthly_mean' rimossa da CEFD.csv
# Colonna 'monthly_mean' rimossa da CEFS.csv
# Colonna 'monthly_mean' rimossa da CEMB.csv
# Colonna 'monthly_mean' rimossa da CETF.csv
# Colonna 'monthly_mean' rimossa da CEW.csv
# Colonna 'monthly_mean' rimossa da CFA.csv
# Colonna 'monthly_mean' rimossa da CFCV.csv
# Colonna 'monthly_mean' rimossa da CFO.csv
# Colonna 'monthly_mean' rimossa da CGBL.csv
# Colonna 'monthly_mean' rimossa da CGCB.csv
# Colonna 'monthly_mean' rimossa da CGCP.csv
# Colonna 'monthly_mean' rimossa da CGDG.csv
# Colonna 'monthly_mean' rimossa da CGDV.csv
# Colonna 'monthly_mean' rimossa da CGGO.csv
# Colonna 'monthly_mean' rimossa da CGGR.csv
# Colonna 'monthly_mean' rimossa da CGIE.csv
# Colonna 'monthly_mean' rimossa da CGMS.csv
# Colonna 'monthly_mean' rimossa da CGMU.csv
# Colonna 'monthly_mean' rimossa da CGRO.csv
# Colonna 'monthly_mean' rimossa da CGSD.csv
# Colonna 'monthly_mean' rimossa da CGSM.csv
# Colonna 'monthly_mean' rimossa da CGUS.csv
# Colonna 'monthly_mean' rimossa da CGV.csv
# Colonna 'monthly_mean' rimossa da CGW.csv
# Colonna 'monthly_mean' rimossa da CGXU.csv
# Colonna 'monthly_mean' rimossa da CHAT.csv
# Colonna 'monthly_mean' rimossa da CHAU.csv
# Colonna 'monthly_mean' rimossa da CHB.csv
# Colonna 'monthly_mean' rimossa da CHGX.csv
# Colonna 'monthly_mean' rimossa da CHIC.csv
# Colonna 'monthly_mean' rimossa da CHIE.csv
# Colonna 'monthly_mean' rimossa da CHIH.csv
# Colonna 'monthly_mean' rimossa da CHII.csv
# Colonna 'monthly_mean' rimossa da CHIK.csv
# Colonna 'monthly_mean' rimossa da CHIM.csv
# Colonna 'monthly_mean' rimossa da CHIQ.csv
# Colonna 'monthly_mean' rimossa da CHIR.csv
# Colonna 'monthly_mean' rimossa da CHIS.csv
# Colonna 'monthly_mean' rimossa da CHIU.csv
# Colonna 'monthly_mean' rimossa da CHIX.csv
# Colonna 'monthly_mean' rimossa da CHPS.csv
# Colonna 'monthly_mean' rimossa da CHRG.csv
# Colonna 'monthly_mean' rimossa da CIBR.csv
# Colonna 'monthly_mean' rimossa da CID.csv
# Colonna 'monthly_mean' rimossa da CIL.csv
# Colonna 'monthly_mean' rimossa da CIRC.csv
# Colonna 'monthly_mean' rimossa da CIZ.csv
# Colonna 'monthly_mean' rimossa da CLDL.csv
# Colonna 'monthly_mean' rimossa da CLIA.csv
# Colonna 'monthly_mean' rimossa da CLIP.csv
# Colonna 'monthly_mean' rimossa da CLIX.csv
# Colonna 'monthly_mean' rimossa da CLNR.csv
# Colonna 'monthly_mean' rimossa da CLOA.csv
# Colonna 'monthly_mean' rimossa da CLOI.csv
# Colonna 'monthly_mean' rimossa da CLOU.csv
# Colonna 'monthly_mean' rimossa da CLOX.csv
# Colonna 'monthly_mean' rimossa da CLOZ.csv
# Colonna 'monthly_mean' rimossa da CLRG.csv
# Colonna 'monthly_mean' rimossa da CLSA.csv
# Colonna 'monthly_mean' rimossa da CLSC.csv
# Colonna 'monthly_mean' rimossa da CLSE.csv
# Colonna 'monthly_mean' rimossa da CLSM.csv
# Colonna 'monthly_mean' rimossa da CMBS.csv
# Colonna 'monthly_mean' rimossa da CMCI.csv
# Colonna 'monthly_mean' rimossa da CMDT.csv
# Colonna 'monthly_mean' rimossa da CMDY.csv
# Colonna 'monthly_mean' rimossa da CMF.csv
# Colonna 'monthly_mean' rimossa da CN.csv
# Colonna 'monthly_mean' rimossa da CNBS.csv
# Colonna 'monthly_mean' rimossa da CNCR.csv
# Colonna 'monthly_mean' rimossa da CNRG.csv
# Colonna 'monthly_mean' rimossa da CNXT.csv
# Colonna 'monthly_mean' rimossa da CNYA.csv
# Colonna 'monthly_mean' rimossa da COM.csv
# Colonna 'monthly_mean' rimossa da COMB.csv
# Colonna 'monthly_mean' rimossa da COMT.csv
# Colonna 'monthly_mean' rimossa da CONL.csv
# Colonna 'monthly_mean' rimossa da CONY.csv
# Colonna 'monthly_mean' rimossa da COPJ.csv
# Colonna 'monthly_mean' rimossa da COPX.csv
# Colonna 'monthly_mean' rimossa da CORN.csv
# Colonna 'monthly_mean' rimossa da CORP.csv
# Colonna 'monthly_mean' rimossa da COWG.csv
# Colonna 'monthly_mean' rimossa da COWS.csv
# Colonna 'monthly_mean' rimossa da COWZ.csv
# Colonna 'monthly_mean' rimossa da CPER.csv
# Colonna 'monthly_mean' rimossa da CPI.csv
# Colonna 'monthly_mean' rimossa da CPII.csv
# Colonna 'monthly_mean' rimossa da CQQQ.csv
# Colonna 'monthly_mean' rimossa da CRAK.csv
# Colonna 'monthly_mean' rimossa da CRBN.csv
# Colonna 'monthly_mean' rimossa da CRDT.csv
# Colonna 'monthly_mean' rimossa da CRED.csv
# Colonna 'monthly_mean' rimossa da CRIT.csv
# Colonna 'monthly_mean' rimossa da CRPT.csv
# Colonna 'monthly_mean' rimossa da CRTC.csv
# Colonna 'monthly_mean' rimossa da CRUZ.csv
# Colonna 'monthly_mean' rimossa da CSA.csv
# Colonna 'monthly_mean' rimossa da CSB.csv
# Colonna 'monthly_mean' rimossa da CSD.csv
# Colonna 'monthly_mean' rimossa da CSF.csv
# Colonna 'monthly_mean' rimossa da CSHI.csv
# Colonna 'monthly_mean' rimossa da CSM.csv
# Colonna 'monthly_mean' rimossa da CSMD.csv
# Colonna 'monthly_mean' rimossa da CSML.csv
# Colonna 'monthly_mean' rimossa da CTA.csv
# Colonna 'monthly_mean' rimossa da CTEC.csv
# Colonna 'monthly_mean' rimossa da CTEX.csv
# Colonna 'monthly_mean' rimossa da CURE.csv
# Colonna 'monthly_mean' rimossa da CUT.csv
# Colonna 'monthly_mean' rimossa da CVAR.csv
# Colonna 'monthly_mean' rimossa da CVIE.csv
# Colonna 'monthly_mean' rimossa da CVLC.csv
# Colonna 'monthly_mean' rimossa da CVMC.csv
# Colonna 'monthly_mean' rimossa da CVRD.csv
# Colonna 'monthly_mean' rimossa da CVRT.csv
# Colonna 'monthly_mean' rimossa da CVSB.csv
# Colonna 'monthly_mean' rimossa da CVSE.csv
# Colonna 'monthly_mean' rimossa da CVY.csv
# Colonna 'monthly_mean' rimossa da CWB.csv
# Colonna 'monthly_mean' rimossa da CWEB.csv
# Colonna 'monthly_mean' rimossa da CWI.csv
# Colonna 'monthly_mean' rimossa da CWS.csv
# Colonna 'monthly_mean' rimossa da CXSE.csv
# Colonna 'monthly_mean' rimossa da CYA.csv
# Colonna 'monthly_mean' rimossa da CZA.csv
# Colonna 'monthly_mean' rimossa da DALI.csv
# Colonna 'monthly_mean' rimossa da DALT.csv
# Colonna 'monthly_mean' rimossa da DAPP.csv
# Colonna 'monthly_mean' rimossa da DAPR.csv
# Colonna 'monthly_mean' rimossa da DARP.csv
# Colonna 'monthly_mean' rimossa da DAT.csv
# Colonna 'monthly_mean' rimossa da DAUG.csv
# Colonna 'monthly_mean' rimossa da DAX.csv
# Colonna 'monthly_mean' rimossa da DBA.csv
# Colonna 'monthly_mean' rimossa da DBAW.csv
# Colonna 'monthly_mean' rimossa da DBB.csv
# Colonna 'monthly_mean' rimossa da DBC.csv
# Colonna 'monthly_mean' rimossa da DBE.csv
# Colonna 'monthly_mean' rimossa da DBEF.csv
# Colonna 'monthly_mean' rimossa da DBEH.csv
# Colonna 'monthly_mean' rimossa da DBEM.csv
# Colonna 'monthly_mean' rimossa da DBEU.csv
# Colonna 'monthly_mean' rimossa da DBEZ.csv
# Colonna 'monthly_mean' rimossa da DBGR.csv
# Colonna 'monthly_mean' rimossa da DBJA.csv
# Colonna 'monthly_mean' rimossa da DBJP.csv
# Colonna 'monthly_mean' rimossa da DBMF.csv
# Colonna 'monthly_mean' rimossa da DBND.csv
# Colonna 'monthly_mean' rimossa da DBO.csv
# Colonna 'monthly_mean' rimossa da DBP.csv
# Colonna 'monthly_mean' rimossa da DCMB.csv
# Colonna 'monthly_mean' rimossa da DCOR.csv
# Colonna 'monthly_mean' rimossa da DDEC.csv
# Colonna 'monthly_mean' rimossa da DDIV.csv
# Colonna 'monthly_mean' rimossa da DDLS.csv
# Colonna 'monthly_mean' rimossa da DDM.csv
# Colonna 'monthly_mean' rimossa da DDWM.csv
# Colonna 'monthly_mean' rimossa da DECT.csv
# Colonna 'monthly_mean' rimossa da DECW.csv
# Colonna 'monthly_mean' rimossa da DECZ.csv
# Colonna 'monthly_mean' rimossa da DEED.csv
# Colonna 'monthly_mean' rimossa da DEEF.csv
# Colonna 'monthly_mean' rimossa da DEEP.csv
# Colonna 'monthly_mean' rimossa da DEFI.csv
# Colonna 'monthly_mean' rimossa da DEHP.csv
# Colonna 'monthly_mean' rimossa da DEIF.csv
# Colonna 'monthly_mean' rimossa da DEM.csv
# Colonna 'monthly_mean' rimossa da DEMZ.csv
# Colonna 'monthly_mean' rimossa da DES.csv
# Colonna 'monthly_mean' rimossa da DESK.csv
# Colonna 'monthly_mean' rimossa da DEUS.csv
# Colonna 'monthly_mean' rimossa da DEW.csv
# Colonna 'monthly_mean' rimossa da DFAC.csv
# Colonna 'monthly_mean' rimossa da DFAE.csv
# Colonna 'monthly_mean' rimossa da DFAI.csv
# Colonna 'monthly_mean' rimossa da DFAR.csv
# Colonna 'monthly_mean' rimossa da DFAS.csv
# Colonna 'monthly_mean' rimossa da DFAT.csv
# Colonna 'monthly_mean' rimossa da DFAU.csv
# Colonna 'monthly_mean' rimossa da DFAW.csv
# Colonna 'monthly_mean' rimossa da DFAX.csv
# Colonna 'monthly_mean' rimossa da DFCA.csv
# Colonna 'monthly_mean' rimossa da DFCF.csv
# Colonna 'monthly_mean' rimossa da DFE.csv
# Colonna 'monthly_mean' rimossa da DFEB.csv
# Colonna 'monthly_mean' rimossa da DFEM.csv
# Colonna 'monthly_mean' rimossa da DFEN.csv
# Colonna 'monthly_mean' rimossa da DFEV.csv
# Colonna 'monthly_mean' rimossa da DFGP.csv
# Colonna 'monthly_mean' rimossa da DFGR.csv
# Colonna 'monthly_mean' rimossa da DFGX.csv
# Colonna 'monthly_mean' rimossa da DFHY.csv
# Colonna 'monthly_mean' rimossa da DFIC.csv
# Colonna 'monthly_mean' rimossa da DFIP.csv
# Colonna 'monthly_mean' rimossa da DFIS.csv
# Colonna 'monthly_mean' rimossa da DFIV.csv
# Colonna 'monthly_mean' rimossa da DFJ.csv
# Colonna 'monthly_mean' rimossa da DFLV.csv
# Colonna 'monthly_mean' rimossa da DFND.csv
# Colonna 'monthly_mean' rimossa da DFNL.csv
# Colonna 'monthly_mean' rimossa da DFNM.csv
# Colonna 'monthly_mean' rimossa da DFNV.csv
# Colonna 'monthly_mean' rimossa da DFRA.csv
# Colonna 'monthly_mean' rimossa da DFSB.csv
# Colonna 'monthly_mean' rimossa da DFSD.csv
# Colonna 'monthly_mean' rimossa da DFSE.csv
# Colonna 'monthly_mean' rimossa da DFSI.csv
# Colonna 'monthly_mean' rimossa da DFSU.csv
# Colonna 'monthly_mean' rimossa da DFSV.csv
# Colonna 'monthly_mean' rimossa da DFUS.csv
# Colonna 'monthly_mean' rimossa da DFUV.csv
# Colonna 'monthly_mean' rimossa da DFVX.csv
# Colonna 'monthly_mean' rimossa da DGCB.csv
# Colonna 'monthly_mean' rimossa da DGIN.csv
# Colonna 'monthly_mean' rimossa da DGRE.csv
# Colonna 'monthly_mean' rimossa da DGRO.csv
# Colonna 'monthly_mean' rimossa da DGRS.csv
# Colonna 'monthly_mean' rimossa da DGRW.csv
# Colonna 'monthly_mean' rimossa da DGS.csv
# Colonna 'monthly_mean' rimossa da DGT.csv
# Colonna 'monthly_mean' rimossa da DHS.csv
# Colonna 'monthly_mean' rimossa da DIA.csv
# Colonna 'monthly_mean' rimossa da DIAL.csv
# Colonna 'monthly_mean' rimossa da DIEM.csv
# Colonna 'monthly_mean' rimossa da DIG.csv
# Colonna 'monthly_mean' rimossa da DIHP.csv
# Colonna 'monthly_mean' rimossa da DIM.csv
# Colonna 'monthly_mean' rimossa da DINT.csv
# Colonna 'monthly_mean' rimossa da DIP.csv
# Colonna 'monthly_mean' rimossa da DISO.csv
# Colonna 'monthly_mean' rimossa da DISV.csv
# Colonna 'monthly_mean' rimossa da DIV.csv
# Colonna 'monthly_mean' rimossa da DIVB.csv
# Colonna 'monthly_mean' rimossa da DIVD.csv
# Colonna 'monthly_mean' rimossa da DIVI.csv
# Colonna 'monthly_mean' rimossa da DIVL.csv
# Colonna 'monthly_mean' rimossa da DIVO.csv
# Colonna 'monthly_mean' rimossa da DIVS.csv
# Colonna 'monthly_mean' rimossa da DIVY.csv
# Colonna 'monthly_mean' rimossa da DIVZ.csv
# Colonna 'monthly_mean' rimossa da DJAN.csv
# Colonna 'monthly_mean' rimossa da DJCB.csv
# Colonna 'monthly_mean' rimossa da DJD.csv
# Colonna 'monthly_mean' rimossa da DJIA.csv
# Colonna 'monthly_mean' rimossa da DJUL.csv
# Colonna 'monthly_mean' rimossa da DJUN.csv
# Colonna 'monthly_mean' rimossa da DKRB.csv
# Colonna 'monthly_mean' rimossa da DLN.csv
# Colonna 'monthly_mean' rimossa da DLS.csv
# Colonna 'monthly_mean' rimossa da DMAR.csv
# Colonna 'monthly_mean' rimossa da DMAT.csv
# Colonna 'monthly_mean' rimossa da DMAY.csv
# Colonna 'monthly_mean' rimossa da DMBS.csv
# Colonna 'monthly_mean' rimossa da DMCY.csv
# Colonna 'monthly_mean' rimossa da DMDV.csv
# Colonna 'monthly_mean' rimossa da DMXF.csv
# Colonna 'monthly_mean' rimossa da DNL.csv
# Colonna 'monthly_mean' rimossa da DNOV.csv
# Colonna 'monthly_mean' rimossa da DOCT.csv
# Colonna 'monthly_mean' rimossa da DOG.csv
# Colonna 'monthly_mean' rimossa da DOGG.csv
# Colonna 'monthly_mean' rimossa da DOL.csv
# Colonna 'monthly_mean' rimossa da DON.csv
# Colonna 'monthly_mean' rimossa da DPST.csv
# Colonna 'monthly_mean' rimossa da DRIP.csv
# Colonna 'monthly_mean' rimossa da DRIV.csv
# Colonna 'monthly_mean' rimossa da DRLL.csv
# Colonna 'monthly_mean' rimossa da DRN.csv
# Colonna 'monthly_mean' rimossa da DRSK.csv
# Colonna 'monthly_mean' rimossa da DRUP.csv
# Colonna 'monthly_mean' rimossa da DRV.csv
# Colonna 'monthly_mean' rimossa da DSCF.csv
# Colonna 'monthly_mean' rimossa da DSEP.csv
# Colonna 'monthly_mean' rimossa da DSI.csv
# Colonna 'monthly_mean' rimossa da DSJA.csv
# Colonna 'monthly_mean' rimossa da DSMC.csv
# Colonna 'monthly_mean' rimossa da DSTL.csv
# Colonna 'monthly_mean' rimossa da DSTX.csv
# Colonna 'monthly_mean' rimossa da DTD.csv
# Colonna 'monthly_mean' rimossa da DTEC.csv
# Colonna 'monthly_mean' rimossa da DTH.csv
# Colonna 'monthly_mean' rimossa da DTRE.csv
# Colonna 'monthly_mean' rimossa da DUBS.csv
# Colonna 'monthly_mean' rimossa da DUG.csv
# Colonna 'monthly_mean' rimossa da DUHP.csv
# Colonna 'monthly_mean' rimossa da DULL.csv
# Colonna 'monthly_mean' rimossa da DURA.csv
# Colonna 'monthly_mean' rimossa da DUSA.csv
# Colonna 'monthly_mean' rimossa da DUSB.csv
# Colonna 'monthly_mean' rimossa da DUSL.csv
# Colonna 'monthly_mean' rimossa da DUST.csv
# Colonna 'monthly_mean' rimossa da DVAL.csv
# Colonna 'monthly_mean' rimossa da DVDN.csv
# Colonna 'monthly_mean' rimossa da DVLU.csv
# Colonna 'monthly_mean' rimossa da DVND.csv
# Colonna 'monthly_mean' rimossa da DVOL.csv
# Colonna 'monthly_mean' rimossa da DVY.csv
# Colonna 'monthly_mean' rimossa da DVYA.csv
# Colonna 'monthly_mean' rimossa da DVYE.csv
# Colonna 'monthly_mean' rimossa da DWAS.csv
# Colonna 'monthly_mean' rimossa da DWAT.csv
# Colonna 'monthly_mean' rimossa da DWAW.csv
# Colonna 'monthly_mean' rimossa da DWCR.csv
# Colonna 'monthly_mean' rimossa da DWLD.csv
# Colonna 'monthly_mean' rimossa da DWM.csv
# Colonna 'monthly_mean' rimossa da DWMF.csv
# Colonna 'monthly_mean' rimossa da DWSH.csv
# Colonna 'monthly_mean' rimossa da DWUS.csv
# Colonna 'monthly_mean' rimossa da DWX.csv
# Colonna 'monthly_mean' rimossa da DXD.csv
# Colonna 'monthly_mean' rimossa da DXJ.csv
# Colonna 'monthly_mean' rimossa da DXJS.csv
# Colonna 'monthly_mean' rimossa da DYLD.csv
# Colonna 'monthly_mean' rimossa da DYLG.csv
# Colonna 'monthly_mean' rimossa da DYNF.csv
# Colonna 'monthly_mean' rimossa da DYNI.csv
# Colonna 'monthly_mean' rimossa da DYTA.csv
# Colonna 'monthly_mean' rimossa da EAGG.csv
# Colonna 'monthly_mean' rimossa da EALT.csv
# Colonna 'monthly_mean' rimossa da EAOA.csv
# Colonna 'monthly_mean' rimossa da EAOK.csv
# Colonna 'monthly_mean' rimossa da EAOM.csv
# Colonna 'monthly_mean' rimossa da EAOR.csv
# Colonna 'monthly_mean' rimossa da EAPR.csv
# Colonna 'monthly_mean' rimossa da EASG.csv
# Colonna 'monthly_mean' rimossa da output_file_0.csv
# Colonna 'monthly_mean' rimossa da output_file_1.csv
# Colonna 'monthly_mean' rimossa da output_file_10.csv
# Colonna 'monthly_mean' rimossa da output_file_100.csv
# Colonna 'monthly_mean' rimossa da output_file_101.csv
# Colonna 'monthly_mean' rimossa da output_file_102.csv
# Colonna 'monthly_mean' rimossa da output_file_103.csv
# Colonna 'monthly_mean' rimossa da output_file_104.csv
# Colonna 'monthly_mean' rimossa da output_file_105.csv
# Colonna 'monthly_mean' rimossa da output_file_106.csv
# Colonna 'monthly_mean' rimossa da output_file_107.csv
# Colonna 'monthly_mean' rimossa da output_file_108.csv
# Colonna 'monthly_mean' rimossa da output_file_109.csv
# Colonna 'monthly_mean' rimossa da output_file_11.csv
# Colonna 'monthly_mean' rimossa da output_file_110.csv
# Colonna 'monthly_mean' rimossa da output_file_111.csv
# Colonna 'monthly_mean' rimossa da output_file_112.csv
# Colonna 'monthly_mean' rimossa da output_file_113.csv
# Colonna 'monthly_mean' rimossa da output_file_114.csv
# Colonna 'monthly_mean' rimossa da output_file_115.csv
# Colonna 'monthly_mean' rimossa da output_file_116.csv
# Colonna 'monthly_mean' rimossa da output_file_117.csv
# Colonna 'monthly_mean' rimossa da output_file_118.csv
# Colonna 'monthly_mean' rimossa da output_file_119.csv
# Colonna 'monthly_mean' rimossa da output_file_12.csv
# Colonna 'monthly_mean' rimossa da output_file_120.csv
# Colonna 'monthly_mean' rimossa da output_file_121.csv
# Colonna 'monthly_mean' rimossa da output_file_122.csv
# Colonna 'monthly_mean' rimossa da output_file_123.csv
# Colonna 'monthly_mean' rimossa da output_file_124.csv
# Colonna 'monthly_mean' rimossa da output_file_125.csv
# Colonna 'monthly_mean' rimossa da output_file_126.csv
# Colonna 'monthly_mean' rimossa da output_file_127.csv
# Colonna 'monthly_mean' rimossa da output_file_128.csv
# Colonna 'monthly_mean' rimossa da output_file_129.csv
# Colonna 'monthly_mean' rimossa da output_file_13.csv
# Colonna 'monthly_mean' rimossa da output_file_130.csv
# Colonna 'monthly_mean' rimossa da output_file_131.csv
# Colonna 'monthly_mean' rimossa da output_file_132.csv
# Colonna 'monthly_mean' rimossa da output_file_133.csv
# Colonna 'monthly_mean' rimossa da output_file_134.csv
# Colonna 'monthly_mean' rimossa da output_file_135.csv
# Colonna 'monthly_mean' rimossa da output_file_136.csv
# Colonna 'monthly_mean' rimossa da output_file_137.csv
# Colonna 'monthly_mean' rimossa da output_file_138.csv
# Colonna 'monthly_mean' rimossa da output_file_139.csv
# Colonna 'monthly_mean' rimossa da output_file_14.csv
# Colonna 'monthly_mean' rimossa da output_file_140.csv
# Colonna 'monthly_mean' rimossa da output_file_141.csv
# Colonna 'monthly_mean' rimossa da output_file_142.csv
# Colonna 'monthly_mean' rimossa da output_file_143.csv
# Colonna 'monthly_mean' rimossa da output_file_144.csv
# Colonna 'monthly_mean' rimossa da output_file_145.csv
# Colonna 'monthly_mean' rimossa da output_file_146.csv
# Colonna 'monthly_mean' rimossa da output_file_147.csv
# Colonna 'monthly_mean' rimossa da output_file_148.csv
# Colonna 'monthly_mean' rimossa da output_file_149.csv
# Colonna 'monthly_mean' rimossa da output_file_15.csv
# Colonna 'monthly_mean' rimossa da output_file_150.csv
# Colonna 'monthly_mean' rimossa da output_file_151.csv
# Colonna 'monthly_mean' rimossa da output_file_152.csv
# Colonna 'monthly_mean' rimossa da output_file_153.csv
# Colonna 'monthly_mean' rimossa da output_file_154.csv
# Colonna 'monthly_mean' rimossa da output_file_155.csv
# Colonna 'monthly_mean' rimossa da output_file_156.csv
# Colonna 'monthly_mean' rimossa da output_file_157.csv
# Colonna 'monthly_mean' rimossa da output_file_158.csv
# Colonna 'monthly_mean' rimossa da output_file_159.csv
# Colonna 'monthly_mean' rimossa da output_file_16.csv
# Colonna 'monthly_mean' rimossa da output_file_160.csv
# Colonna 'monthly_mean' rimossa da output_file_161.csv
# Colonna 'monthly_mean' rimossa da output_file_162.csv
# Colonna 'monthly_mean' rimossa da output_file_163.csv
# Colonna 'monthly_mean' rimossa da output_file_164.csv
# Colonna 'monthly_mean' rimossa da output_file_165.csv
# Colonna 'monthly_mean' rimossa da output_file_166.csv
# Colonna 'monthly_mean' rimossa da output_file_167.csv
# Colonna 'monthly_mean' rimossa da output_file_168.csv
# Colonna 'monthly_mean' rimossa da output_file_169.csv
# Colonna 'monthly_mean' rimossa da output_file_17.csv
# Colonna 'monthly_mean' rimossa da output_file_170.csv
# Colonna 'monthly_mean' rimossa da output_file_171.csv
# Colonna 'monthly_mean' rimossa da output_file_172.csv
# Colonna 'monthly_mean' rimossa da output_file_173.csv
# Colonna 'monthly_mean' rimossa da output_file_174.csv
# Colonna 'monthly_mean' rimossa da output_file_175.csv
# Colonna 'monthly_mean' rimossa da output_file_176.csv
# Colonna 'monthly_mean' rimossa da output_file_177.csv
# Colonna 'monthly_mean' rimossa da output_file_178.csv
# Colonna 'monthly_mean' rimossa da output_file_179.csv
# Colonna 'monthly_mean' rimossa da output_file_18.csv
# Colonna 'monthly_mean' rimossa da output_file_180.csv
# Colonna 'monthly_mean' rimossa da output_file_181.csv
# Colonna 'monthly_mean' rimossa da output_file_182.csv
# Colonna 'monthly_mean' rimossa da output_file_183.csv
# Colonna 'monthly_mean' rimossa da output_file_184.csv
# Colonna 'monthly_mean' rimossa da output_file_185.csv
# Colonna 'monthly_mean' rimossa da output_file_186.csv
# Colonna 'monthly_mean' rimossa da output_file_187.csv
# Colonna 'monthly_mean' rimossa da output_file_188.csv
# Colonna 'monthly_mean' rimossa da output_file_189.csv
# Colonna 'monthly_mean' rimossa da output_file_19.csv
# Colonna 'monthly_mean' rimossa da output_file_190.csv
# Colonna 'monthly_mean' rimossa da output_file_191.csv
# Colonna 'monthly_mean' rimossa da output_file_192.csv
# Colonna 'monthly_mean' rimossa da output_file_193.csv
# Colonna 'monthly_mean' rimossa da output_file_194.csv
# Colonna 'monthly_mean' rimossa da output_file_195.csv
# Colonna 'monthly_mean' rimossa da output_file_196.csv
# Colonna 'monthly_mean' rimossa da output_file_197.csv
# Colonna 'monthly_mean' rimossa da output_file_198.csv
# Colonna 'monthly_mean' rimossa da output_file_199.csv
# Colonna 'monthly_mean' rimossa da output_file_2.csv
# Colonna 'monthly_mean' rimossa da output_file_20.csv
# Colonna 'monthly_mean' rimossa da output_file_200.csv
# Colonna 'monthly_mean' rimossa da output_file_201.csv
# Colonna 'monthly_mean' rimossa da output_file_202.csv
# Colonna 'monthly_mean' rimossa da output_file_203.csv
# Colonna 'monthly_mean' rimossa da output_file_204.csv
# Colonna 'monthly_mean' rimossa da output_file_205.csv
# Colonna 'monthly_mean' rimossa da output_file_206.csv
# Colonna 'monthly_mean' rimossa da output_file_207.csv
# Colonna 'monthly_mean' rimossa da output_file_208.csv
# Colonna 'monthly_mean' rimossa da output_file_209.csv
# Colonna 'monthly_mean' rimossa da output_file_21.csv
# Colonna 'monthly_mean' rimossa da output_file_210.csv
# Colonna 'monthly_mean' rimossa da output_file_211.csv
# Colonna 'monthly_mean' rimossa da output_file_212.csv
# Colonna 'monthly_mean' rimossa da output_file_213.csv
# Colonna 'monthly_mean' rimossa da output_file_214.csv
# Colonna 'monthly_mean' rimossa da output_file_215.csv
# Colonna 'monthly_mean' rimossa da output_file_216.csv
# Colonna 'monthly_mean' rimossa da output_file_217.csv
# Colonna 'monthly_mean' rimossa da output_file_218.csv
# Colonna 'monthly_mean' rimossa da output_file_219.csv
# Colonna 'monthly_mean' rimossa da output_file_22.csv
# Colonna 'monthly_mean' rimossa da output_file_220.csv
# Colonna 'monthly_mean' rimossa da output_file_221.csv
# Colonna 'monthly_mean' rimossa da output_file_222.csv
# Colonna 'monthly_mean' rimossa da output_file_223.csv
# Colonna 'monthly_mean' rimossa da output_file_224.csv
# Colonna 'monthly_mean' rimossa da output_file_225.csv
# Colonna 'monthly_mean' rimossa da output_file_226.csv
# Colonna 'monthly_mean' rimossa da output_file_227.csv
# Colonna 'monthly_mean' rimossa da output_file_228.csv
# Colonna 'monthly_mean' rimossa da output_file_229.csv
# Colonna 'monthly_mean' rimossa da output_file_23.csv
# Colonna 'monthly_mean' rimossa da output_file_230.csv
# Colonna 'monthly_mean' rimossa da output_file_231.csv
# Colonna 'monthly_mean' rimossa da output_file_232.csv
# Colonna 'monthly_mean' rimossa da output_file_233.csv
# Colonna 'monthly_mean' rimossa da output_file_234.csv
# Colonna 'monthly_mean' rimossa da output_file_235.csv
# Colonna 'monthly_mean' rimossa da output_file_236.csv
# Colonna 'monthly_mean' rimossa da output_file_237.csv
# Colonna 'monthly_mean' rimossa da output_file_238.csv
# Colonna 'monthly_mean' rimossa da output_file_239.csv
# Colonna 'monthly_mean' rimossa da output_file_24.csv
# Colonna 'monthly_mean' rimossa da output_file_240.csv
# Colonna 'monthly_mean' rimossa da output_file_241.csv
# Colonna 'monthly_mean' rimossa da output_file_242.csv
# Colonna 'monthly_mean' rimossa da output_file_243.csv
# Colonna 'monthly_mean' rimossa da output_file_244.csv
# Colonna 'monthly_mean' rimossa da output_file_245.csv
# Colonna 'monthly_mean' rimossa da output_file_246.csv
# Colonna 'monthly_mean' rimossa da output_file_247.csv
# Colonna 'monthly_mean' rimossa da output_file_248.csv
# Colonna 'monthly_mean' rimossa da output_file_249.csv
# Colonna 'monthly_mean' rimossa da output_file_25.csv
# Colonna 'monthly_mean' rimossa da output_file_250.csv
# Colonna 'monthly_mean' rimossa da output_file_251.csv
# Colonna 'monthly_mean' rimossa da output_file_252.csv
# Colonna 'monthly_mean' rimossa da output_file_253.csv
# Colonna 'monthly_mean' rimossa da output_file_254.csv
# Colonna 'monthly_mean' rimossa da output_file_255.csv
# Colonna 'monthly_mean' rimossa da output_file_256.csv
# Colonna 'monthly_mean' rimossa da output_file_257.csv
# Colonna 'monthly_mean' rimossa da output_file_258.csv
# Colonna 'monthly_mean' rimossa da output_file_259.csv
# Colonna 'monthly_mean' rimossa da output_file_26.csv
# Colonna 'monthly_mean' rimossa da output_file_260.csv
# Colonna 'monthly_mean' rimossa da output_file_261.csv
# Colonna 'monthly_mean' rimossa da output_file_262.csv
# Colonna 'monthly_mean' rimossa da output_file_263.csv
# Colonna 'monthly_mean' rimossa da output_file_264.csv
# Colonna 'monthly_mean' rimossa da output_file_265.csv
# Colonna 'monthly_mean' rimossa da output_file_266.csv
# Colonna 'monthly_mean' rimossa da output_file_267.csv
# Colonna 'monthly_mean' rimossa da output_file_268.csv
# Colonna 'monthly_mean' rimossa da output_file_269.csv
# Colonna 'monthly_mean' rimossa da output_file_27.csv
# Colonna 'monthly_mean' rimossa da output_file_270.csv
# Colonna 'monthly_mean' rimossa da output_file_271.csv
# Colonna 'monthly_mean' rimossa da output_file_272.csv
# Colonna 'monthly_mean' rimossa da output_file_273.csv
# Colonna 'monthly_mean' rimossa da output_file_274.csv
# Colonna 'monthly_mean' rimossa da output_file_275.csv
# Colonna 'monthly_mean' rimossa da output_file_276.csv
# Colonna 'monthly_mean' rimossa da output_file_277.csv
# Colonna 'monthly_mean' rimossa da output_file_278.csv
# Colonna 'monthly_mean' rimossa da output_file_279.csv
# Colonna 'monthly_mean' rimossa da output_file_28.csv
# Colonna 'monthly_mean' rimossa da output_file_280.csv
# Colonna 'monthly_mean' rimossa da output_file_281.csv
# Colonna 'monthly_mean' rimossa da output_file_282.csv
# Colonna 'monthly_mean' rimossa da output_file_283.csv
# Colonna 'monthly_mean' rimossa da output_file_284.csv
# Colonna 'monthly_mean' rimossa da output_file_285.csv
# Colonna 'monthly_mean' rimossa da output_file_286.csv
# Colonna 'monthly_mean' rimossa da output_file_287.csv
# Colonna 'monthly_mean' rimossa da output_file_288.csv
# Colonna 'monthly_mean' rimossa da output_file_289.csv
# Colonna 'monthly_mean' rimossa da output_file_29.csv
# Colonna 'monthly_mean' rimossa da output_file_290.csv
# Colonna 'monthly_mean' rimossa da output_file_291.csv
# Colonna 'monthly_mean' rimossa da output_file_292.csv
# Colonna 'monthly_mean' rimossa da output_file_293.csv
# Colonna 'monthly_mean' rimossa da output_file_294.csv
# Colonna 'monthly_mean' rimossa da output_file_295.csv
# Colonna 'monthly_mean' rimossa da output_file_296.csv
# Colonna 'monthly_mean' rimossa da output_file_297.csv
# Colonna 'monthly_mean' rimossa da output_file_298.csv
# Colonna 'monthly_mean' rimossa da output_file_299.csv
# Colonna 'monthly_mean' rimossa da output_file_3.csv
# Colonna 'monthly_mean' rimossa da output_file_30.csv
# Colonna 'monthly_mean' rimossa da output_file_300.csv
# Colonna 'monthly_mean' rimossa da output_file_301.csv
# Colonna 'monthly_mean' rimossa da output_file_302.csv
# Colonna 'monthly_mean' rimossa da output_file_303.csv
# Colonna 'monthly_mean' rimossa da output_file_304.csv
# Colonna 'monthly_mean' rimossa da output_file_305.csv
# Colonna 'monthly_mean' rimossa da output_file_306.csv
# Colonna 'monthly_mean' rimossa da output_file_307.csv
# Colonna 'monthly_mean' rimossa da output_file_308.csv
# Colonna 'monthly_mean' rimossa da output_file_309.csv
# Colonna 'monthly_mean' rimossa da output_file_31.csv
# Colonna 'monthly_mean' rimossa da output_file_310.csv
# Colonna 'monthly_mean' rimossa da output_file_311.csv
# Colonna 'monthly_mean' rimossa da output_file_312.csv
# Colonna 'monthly_mean' rimossa da output_file_313.csv
# Colonna 'monthly_mean' rimossa da output_file_314.csv
# Colonna 'monthly_mean' rimossa da output_file_315.csv
# Colonna 'monthly_mean' rimossa da output_file_316.csv
# Colonna 'monthly_mean' rimossa da output_file_317.csv
# Colonna 'monthly_mean' rimossa da output_file_318.csv
# Colonna 'monthly_mean' rimossa da output_file_319.csv
# Colonna 'monthly_mean' rimossa da output_file_32.csv
# Colonna 'monthly_mean' rimossa da output_file_320.csv
# Colonna 'monthly_mean' rimossa da output_file_321.csv
# Colonna 'monthly_mean' rimossa da output_file_322.csv
# Colonna 'monthly_mean' rimossa da output_file_323.csv
# Colonna 'monthly_mean' rimossa da output_file_324.csv
# Colonna 'monthly_mean' rimossa da output_file_325.csv
# Colonna 'monthly_mean' rimossa da output_file_326.csv
# Colonna 'monthly_mean' rimossa da output_file_327.csv
# Colonna 'monthly_mean' rimossa da output_file_328.csv
# Colonna 'monthly_mean' rimossa da output_file_329.csv
# Colonna 'monthly_mean' rimossa da output_file_33.csv
# Colonna 'monthly_mean' rimossa da output_file_330.csv
# Colonna 'monthly_mean' rimossa da output_file_331.csv
# Colonna 'monthly_mean' rimossa da output_file_332.csv
# Colonna 'monthly_mean' rimossa da output_file_333.csv
# Colonna 'monthly_mean' rimossa da output_file_334.csv
# Colonna 'monthly_mean' rimossa da output_file_335.csv
# Colonna 'monthly_mean' rimossa da output_file_336.csv
# Colonna 'monthly_mean' rimossa da output_file_337.csv
# Colonna 'monthly_mean' rimossa da output_file_338.csv
# Colonna 'monthly_mean' rimossa da output_file_339.csv
# Colonna 'monthly_mean' rimossa da output_file_34.csv
# Colonna 'monthly_mean' rimossa da output_file_340.csv
# Colonna 'monthly_mean' rimossa da output_file_341.csv
# Colonna 'monthly_mean' rimossa da output_file_342.csv
# Colonna 'monthly_mean' rimossa da output_file_343.csv
# Colonna 'monthly_mean' rimossa da output_file_344.csv
# Colonna 'monthly_mean' rimossa da output_file_345.csv
# Colonna 'monthly_mean' rimossa da output_file_346.csv
# Colonna 'monthly_mean' rimossa da output_file_347.csv
# Colonna 'monthly_mean' rimossa da output_file_348.csv
# Colonna 'monthly_mean' rimossa da output_file_349.csv
# Colonna 'monthly_mean' rimossa da output_file_35.csv
# Colonna 'monthly_mean' rimossa da output_file_350.csv
# Colonna 'monthly_mean' rimossa da output_file_351.csv
# Colonna 'monthly_mean' rimossa da output_file_352.csv
# Colonna 'monthly_mean' rimossa da output_file_353.csv
# Colonna 'monthly_mean' rimossa da output_file_354.csv
# Colonna 'monthly_mean' rimossa da output_file_355.csv
# Colonna 'monthly_mean' rimossa da output_file_356.csv
# Colonna 'monthly_mean' rimossa da output_file_357.csv
# Colonna 'monthly_mean' rimossa da output_file_358.csv
# Colonna 'monthly_mean' rimossa da output_file_359.csv
# Colonna 'monthly_mean' rimossa da output_file_36.csv
# Colonna 'monthly_mean' rimossa da output_file_360.csv
# Colonna 'monthly_mean' rimossa da output_file_361.csv
# Colonna 'monthly_mean' rimossa da output_file_362.csv
# Colonna 'monthly_mean' rimossa da output_file_363.csv
# Colonna 'monthly_mean' rimossa da output_file_364.csv
# Colonna 'monthly_mean' rimossa da output_file_365.csv
# Colonna 'monthly_mean' rimossa da output_file_366.csv
# Colonna 'monthly_mean' rimossa da output_file_367.csv
# Colonna 'monthly_mean' rimossa da output_file_368.csv
# Colonna 'monthly_mean' rimossa da output_file_369.csv
# Colonna 'monthly_mean' rimossa da output_file_37.csv
# Colonna 'monthly_mean' rimossa da output_file_370.csv
# Colonna 'monthly_mean' rimossa da output_file_371.csv
# Colonna 'monthly_mean' rimossa da output_file_372.csv
# Colonna 'monthly_mean' rimossa da output_file_373.csv
# Colonna 'monthly_mean' rimossa da output_file_374.csv
# Colonna 'monthly_mean' rimossa da output_file_375.csv
# Colonna 'monthly_mean' rimossa da output_file_376.csv
# Colonna 'monthly_mean' rimossa da output_file_377.csv
# Colonna 'monthly_mean' rimossa da output_file_378.csv
# Colonna 'monthly_mean' rimossa da output_file_379.csv
# Colonna 'monthly_mean' rimossa da output_file_38.csv
# Colonna 'monthly_mean' rimossa da output_file_380.csv
# Colonna 'monthly_mean' rimossa da output_file_381.csv
# Colonna 'monthly_mean' rimossa da output_file_382.csv
# Colonna 'monthly_mean' rimossa da output_file_383.csv
# Colonna 'monthly_mean' rimossa da output_file_384.csv
# Colonna 'monthly_mean' rimossa da output_file_385.csv
# Colonna 'monthly_mean' rimossa da output_file_386.csv
# Colonna 'monthly_mean' rimossa da output_file_387.csv
# Colonna 'monthly_mean' rimossa da output_file_388.csv
# Colonna 'monthly_mean' rimossa da output_file_389.csv
# Colonna 'monthly_mean' rimossa da output_file_39.csv
# ...
# Colonna 'monthly_mean' rimossa da output_file_472.csv
# Colonna 'monthly_mean' rimossa da output_file_473.csv
# Colonna 'monthly_mean' rimossa da output_file_474.csv
# Colonna 'monthly_mean' rimossa da output_file_475.csv
# Colonna 'monthly_mean' rimossa da output_file_476.csv
# Colonna 'monthly_mean' rimossa da output_file_477.csv
# Colonna 'monthly_mean' rimossa da output_file_478.csv
# Colonna 'monthly_mean' rimossa da output_file_479.csv
# Colonna 'monthly_mean' rimossa da output_file_48.csv
# Colonna 'monthly_mean' rimossa da output_file_480.csv
# Colonna 'monthly_mean' rimossa da output_file_481.csv
# Colonna 'monthly_mean' rimossa da output_file_482.csv
# Colonna 'monthly_mean' rimossa da output_file_483.csv
# Colonna 'monthly_mean' rimossa da output_file_484.csv
# Colonna 'monthly_mean' rimossa da output_file_485.csv
# Colonna 'monthly_mean' rimossa da output_file_486.csv
# Colonna 'monthly_mean' rimossa da output_file_487.csv
# Colonna 'monthly_mean' rimossa da output_file_488.csv
# Colonna 'monthly_mean' rimossa da output_file_489.csv
# Colonna 'monthly_mean' rimossa da output_file_49.csv
# Colonna 'monthly_mean' rimossa da output_file_490.csv
# Colonna 'monthly_mean' rimossa da output_file_491.csv
# Colonna 'monthly_mean' rimossa da output_file_492.csv
# Colonna 'monthly_mean' rimossa da output_file_493.csv
# Colonna 'monthly_mean' rimossa da output_file_494.csv
# Colonna 'monthly_mean' rimossa da output_file_495.csv
# Colonna 'monthly_mean' rimossa da output_file_496.csv
# Colonna 'monthly_mean' rimossa da output_file_497.csv
# Colonna 'monthly_mean' rimossa da output_file_498.csv
# Colonna 'monthly_mean' rimossa da output_file_499.csv
# Colonna 'monthly_mean' rimossa da output_file_5.csv
# Colonna 'monthly_mean' rimossa da output_file_50.csv
# Colonna 'monthly_mean' rimossa da output_file_500.csv
# Colonna 'monthly_mean' rimossa da output_file_501.csv
# Colonna 'monthly_mean' rimossa da output_file_502.csv
# Colonna 'monthly_mean' rimossa da output_file_503.csv
# Colonna 'monthly_mean' rimossa da output_file_504.csv
# Colonna 'monthly_mean' rimossa da output_file_505.csv
# Colonna 'monthly_mean' rimossa da output_file_506.csv
# Colonna 'monthly_mean' rimossa da output_file_507.csv
# Colonna 'monthly_mean' rimossa da output_file_508.csv
# Colonna 'monthly_mean' rimossa da output_file_509.csv
# Colonna 'monthly_mean' rimossa da output_file_51.csv
# Colonna 'monthly_mean' rimossa da output_file_510.csv
# Colonna 'monthly_mean' rimossa da output_file_511.csv
# Colonna 'monthly_mean' rimossa da output_file_512.csv
# Colonna 'monthly_mean' rimossa da output_file_513.csv
# Colonna 'monthly_mean' rimossa da output_file_514.csv
# Colonna 'monthly_mean' rimossa da output_file_515.csv
# Colonna 'monthly_mean' rimossa da output_file_516.csv
# Colonna 'monthly_mean' rimossa da output_file_517.csv
# Colonna 'monthly_mean' rimossa da output_file_518.csv
# Colonna 'monthly_mean' rimossa da output_file_519.csv
# Colonna 'monthly_mean' rimossa da output_file_52.csv
# Colonna 'monthly_mean' rimossa da output_file_520.csv
# Colonna 'monthly_mean' rimossa da output_file_521.csv
# Colonna 'monthly_mean' rimossa da output_file_522.csv
# Colonna 'monthly_mean' rimossa da output_file_523.csv
# Colonna 'monthly_mean' rimossa da output_file_524.csv
# Colonna 'monthly_mean' rimossa da output_file_525.csv
# Colonna 'monthly_mean' rimossa da output_file_526.csv
# Colonna 'monthly_mean' rimossa da output_file_527.csv
# Colonna 'monthly_mean' rimossa da output_file_528.csv
# Colonna 'monthly_mean' rimossa da output_file_529.csv
# Colonna 'monthly_mean' rimossa da output_file_53.csv
# Colonna 'monthly_mean' rimossa da output_file_530.csv
# Colonna 'monthly_mean' rimossa da output_file_531.csv
# Colonna 'monthly_mean' rimossa da output_file_532.csv
# Colonna 'monthly_mean' rimossa da output_file_533.csv
# Colonna 'monthly_mean' rimossa da output_file_534.csv
# Colonna 'monthly_mean' rimossa da output_file_535.csv
# Colonna 'monthly_mean' rimossa da output_file_536.csv
# Colonna 'monthly_mean' rimossa da output_file_537.csv
# Colonna 'monthly_mean' rimossa da output_file_538.csv
# Colonna 'monthly_mean' rimossa da output_file_539.csv
# Colonna 'monthly_mean' rimossa da output_file_54.csv
# Colonna 'monthly_mean' rimossa da output_file_540.csv
# Colonna 'monthly_mean' rimossa da output_file_541.csv
# Colonna 'monthly_mean' rimossa da output_file_542.csv
# Colonna 'monthly_mean' rimossa da output_file_543.csv
# Colonna 'monthly_mean' rimossa da output_file_544.csv
# Colonna 'monthly_mean' rimossa da output_file_545.csv
# Colonna 'monthly_mean' rimossa da output_file_546.csv
# Colonna 'monthly_mean' rimossa da output_file_547.csv
# Colonna 'monthly_mean' rimossa da output_file_548.csv
# Colonna 'monthly_mean' rimossa da output_file_549.csv
# Colonna 'monthly_mean' rimossa da output_file_55.csv
# Colonna 'monthly_mean' rimossa da output_file_550.csv
# Colonna 'monthly_mean' rimossa da output_file_551.csv
# Colonna 'monthly_mean' rimossa da output_file_552.csv
# Colonna 'monthly_mean' rimossa da output_file_553.csv
# Colonna 'monthly_mean' rimossa da output_file_554.csv
# Colonna 'monthly_mean' rimossa da output_file_555.csv
# Colonna 'monthly_mean' rimossa da output_file_556.csv
# Colonna 'monthly_mean' rimossa da output_file_557.csv
# Colonna 'monthly_mean' rimossa da output_file_558.csv
# Colonna 'monthly_mean' rimossa da output_file_559.csv
# Colonna 'monthly_mean' rimossa da output_file_56.csv
# Colonna 'monthly_mean' rimossa da output_file_560.csv
# Colonna 'monthly_mean' rimossa da output_file_561.csv
# Colonna 'monthly_mean' rimossa da output_file_562.csv
# Colonna 'monthly_mean' rimossa da output_file_563.csv
# Colonna 'monthly_mean' rimossa da output_file_564.csv
# Colonna 'monthly_mean' rimossa da output_file_565.csv
# Colonna 'monthly_mean' rimossa da output_file_566.csv
# Colonna 'monthly_mean' rimossa da output_file_567.csv
# Colonna 'monthly_mean' rimossa da output_file_568.csv
# Colonna 'monthly_mean' rimossa da output_file_569.csv
# Colonna 'monthly_mean' rimossa da output_file_57.csv
# Colonna 'monthly_mean' rimossa da output_file_570.csv
# Colonna 'monthly_mean' rimossa da output_file_571.csv
# Colonna 'monthly_mean' rimossa da output_file_572.csv
# Colonna 'monthly_mean' rimossa da output_file_573.csv
# Colonna 'monthly_mean' rimossa da output_file_574.csv
# Colonna 'monthly_mean' rimossa da output_file_575.csv
# Colonna 'monthly_mean' rimossa da output_file_576.csv
# Colonna 'monthly_mean' rimossa da output_file_577.csv
# Colonna 'monthly_mean' rimossa da output_file_578.csv
# Colonna 'monthly_mean' rimossa da output_file_579.csv
# Colonna 'monthly_mean' rimossa da output_file_58.csv
# Colonna 'monthly_mean' rimossa da output_file_580.csv
# Colonna 'monthly_mean' rimossa da output_file_581.csv
# Colonna 'monthly_mean' rimossa da output_file_582.csv
# Colonna 'monthly_mean' rimossa da output_file_583.csv
# Colonna 'monthly_mean' rimossa da output_file_584.csv
# Colonna 'monthly_mean' rimossa da output_file_585.csv
# Colonna 'monthly_mean' rimossa da output_file_586.csv
# Colonna 'monthly_mean' rimossa da output_file_587.csv
# Colonna 'monthly_mean' rimossa da output_file_588.csv
# Colonna 'monthly_mean' rimossa da output_file_589.csv
# Colonna 'monthly_mean' rimossa da output_file_59.csv
# Colonna 'monthly_mean' rimossa da output_file_590.csv
# Colonna 'monthly_mean' rimossa da output_file_591.csv
# Colonna 'monthly_mean' rimossa da output_file_592.csv
# Colonna 'monthly_mean' rimossa da output_file_593.csv
# Colonna 'monthly_mean' rimossa da output_file_594.csv
# Colonna 'monthly_mean' rimossa da output_file_595.csv
# Colonna 'monthly_mean' rimossa da output_file_596.csv
# Colonna 'monthly_mean' rimossa da output_file_597.csv
# Colonna 'monthly_mean' rimossa da output_file_598.csv
# Colonna 'monthly_mean' rimossa da output_file_599.csv
# Colonna 'monthly_mean' rimossa da output_file_6.csv
# Colonna 'monthly_mean' rimossa da output_file_60.csv
# Colonna 'monthly_mean' rimossa da output_file_600.csv
# Colonna 'monthly_mean' rimossa da output_file_601.csv
# Colonna 'monthly_mean' rimossa da output_file_602.csv
# Colonna 'monthly_mean' rimossa da output_file_603.csv
# Colonna 'monthly_mean' rimossa da output_file_604.csv
# Colonna 'monthly_mean' rimossa da output_file_605.csv
# Colonna 'monthly_mean' rimossa da output_file_606.csv
# Colonna 'monthly_mean' rimossa da output_file_607.csv
# Colonna 'monthly_mean' rimossa da output_file_608.csv
# Colonna 'monthly_mean' rimossa da output_file_609.csv
# Colonna 'monthly_mean' rimossa da output_file_61.csv
# Colonna 'monthly_mean' rimossa da output_file_610.csv
# Colonna 'monthly_mean' rimossa da output_file_611.csv
# Colonna 'monthly_mean' rimossa da output_file_612.csv
# Colonna 'monthly_mean' rimossa da output_file_613.csv
# Colonna 'monthly_mean' rimossa da output_file_614.csv
# Colonna 'monthly_mean' rimossa da output_file_615.csv
# Colonna 'monthly_mean' rimossa da output_file_616.csv
# Colonna 'monthly_mean' rimossa da output_file_617.csv
# Colonna 'monthly_mean' rimossa da output_file_618.csv
# Colonna 'monthly_mean' rimossa da output_file_619.csv
# Colonna 'monthly_mean' rimossa da output_file_62.csv
# Colonna 'monthly_mean' rimossa da output_file_620.csv
# Colonna 'monthly_mean' rimossa da output_file_621.csv
# Colonna 'monthly_mean' rimossa da output_file_622.csv
# Colonna 'monthly_mean' rimossa da output_file_623.csv
# Colonna 'monthly_mean' rimossa da output_file_624.csv
# Colonna 'monthly_mean' rimossa da output_file_625.csv
# Colonna 'monthly_mean' rimossa da output_file_626.csv
# Colonna 'monthly_mean' rimossa da output_file_627.csv
# Colonna 'monthly_mean' rimossa da output_file_628.csv
# Colonna 'monthly_mean' rimossa da output_file_629.csv
# Colonna 'monthly_mean' rimossa da output_file_63.csv
# Colonna 'monthly_mean' rimossa da output_file_630.csv
# Colonna 'monthly_mean' rimossa da output_file_631.csv
# Colonna 'monthly_mean' rimossa da output_file_632.csv
# Colonna 'monthly_mean' rimossa da output_file_633.csv
# Colonna 'monthly_mean' rimossa da output_file_634.csv
# Colonna 'monthly_mean' rimossa da output_file_635.csv
# Colonna 'monthly_mean' rimossa da output_file_636.csv
# Colonna 'monthly_mean' rimossa da output_file_637.csv
# Colonna 'monthly_mean' rimossa da output_file_638.csv
# Colonna 'monthly_mean' rimossa da output_file_639.csv
# Colonna 'monthly_mean' rimossa da output_file_64.csv
# Colonna 'monthly_mean' rimossa da output_file_640.csv
# Colonna 'monthly_mean' rimossa da output_file_641.csv
# Colonna 'monthly_mean' rimossa da output_file_642.csv
# Colonna 'monthly_mean' rimossa da output_file_643.csv
# Colonna 'monthly_mean' rimossa da output_file_644.csv
# Colonna 'monthly_mean' rimossa da output_file_645.csv
# Colonna 'monthly_mean' rimossa da output_file_646.csv
# Colonna 'monthly_mean' rimossa da output_file_647.csv
# Colonna 'monthly_mean' rimossa da output_file_648.csv
# Colonna 'monthly_mean' rimossa da output_file_649.csv
# Colonna 'monthly_mean' rimossa da output_file_65.csv
# Colonna 'monthly_mean' rimossa da output_file_650.csv
# Colonna 'monthly_mean' rimossa da output_file_651.csv
# Colonna 'monthly_mean' rimossa da output_file_652.csv
# Colonna 'monthly_mean' rimossa da output_file_653.csv
# Colonna 'monthly_mean' rimossa da output_file_654.csv
# Colonna 'monthly_mean' rimossa da output_file_655.csv
# Colonna 'monthly_mean' rimossa da output_file_656.csv
# Colonna 'monthly_mean' rimossa da output_file_657.csv
# Colonna 'monthly_mean' rimossa da output_file_658.csv
# Colonna 'monthly_mean' rimossa da output_file_659.csv
# Colonna 'monthly_mean' rimossa da output_file_66.csv
# Colonna 'monthly_mean' rimossa da output_file_660.csv
# Colonna 'monthly_mean' rimossa da output_file_661.csv
# Colonna 'monthly_mean' rimossa da output_file_662.csv
# Colonna 'monthly_mean' rimossa da output_file_663.csv
# Colonna 'monthly_mean' rimossa da output_file_664.csv
# Colonna 'monthly_mean' rimossa da output_file_665.csv
# Colonna 'monthly_mean' rimossa da output_file_666.csv
# Colonna 'monthly_mean' rimossa da output_file_667.csv
# Colonna 'monthly_mean' rimossa da output_file_668.csv
# Colonna 'monthly_mean' rimossa da output_file_669.csv
# Colonna 'monthly_mean' rimossa da output_file_67.csv
# Colonna 'monthly_mean' rimossa da output_file_670.csv
# Colonna 'monthly_mean' rimossa da output_file_671.csv
# Colonna 'monthly_mean' rimossa da output_file_672.csv
# Colonna 'monthly_mean' rimossa da output_file_673.csv
# Colonna 'monthly_mean' rimossa da output_file_674.csv
# Colonna 'monthly_mean' rimossa da output_file_675.csv
# Colonna 'monthly_mean' rimossa da output_file_676.csv
# Colonna 'monthly_mean' rimossa da output_file_677.csv
# Colonna 'monthly_mean' rimossa da output_file_678.csv
# Colonna 'monthly_mean' rimossa da output_file_679.csv
# Colonna 'monthly_mean' rimossa da output_file_68.csv
# Colonna 'monthly_mean' rimossa da output_file_680.csv
# Colonna 'monthly_mean' rimossa da output_file_681.csv
# Colonna 'monthly_mean' rimossa da output_file_682.csv
# Colonna 'monthly_mean' rimossa da output_file_683.csv
# Colonna 'monthly_mean' rimossa da output_file_684.csv
# Colonna 'monthly_mean' rimossa da output_file_685.csv
# Colonna 'monthly_mean' rimossa da output_file_686.csv
# Colonna 'monthly_mean' rimossa da output_file_687.csv
# Colonna 'monthly_mean' rimossa da output_file_688.csv
# Colonna 'monthly_mean' rimossa da output_file_689.csv
# Colonna 'monthly_mean' rimossa da output_file_69.csv
# Colonna 'monthly_mean' rimossa da output_file_690.csv
# Colonna 'monthly_mean' rimossa da output_file_691.csv
# Colonna 'monthly_mean' rimossa da output_file_692.csv
# Colonna 'monthly_mean' rimossa da output_file_693.csv
# Colonna 'monthly_mean' rimossa da output_file_694.csv
# Colonna 'monthly_mean' rimossa da output_file_695.csv
# Colonna 'monthly_mean' rimossa da output_file_696.csv
# Colonna 'monthly_mean' rimossa da output_file_697.csv
# Colonna 'monthly_mean' rimossa da output_file_698.csv
# Colonna 'monthly_mean' rimossa da output_file_699.csv
# Colonna 'monthly_mean' rimossa da output_file_7.csv
# Colonna 'monthly_mean' rimossa da output_file_70.csv
# Colonna 'monthly_mean' rimossa da output_file_700.csv
# Colonna 'monthly_mean' rimossa da output_file_701.csv
# Colonna 'monthly_mean' rimossa da output_file_702.csv
# Colonna 'monthly_mean' rimossa da output_file_703.csv
# Colonna 'monthly_mean' rimossa da output_file_704.csv
# Colonna 'monthly_mean' rimossa da output_file_705.csv
# Colonna 'monthly_mean' rimossa da output_file_706.csv
# Colonna 'monthly_mean' rimossa da output_file_707.csv
# Colonna 'monthly_mean' rimossa da output_file_708.csv
# Colonna 'monthly_mean' rimossa da output_file_709.csv
# Colonna 'monthly_mean' rimossa da output_file_71.csv
# Colonna 'monthly_mean' rimossa da output_file_710.csv
# Colonna 'monthly_mean' rimossa da output_file_711.csv
# Colonna 'monthly_mean' rimossa da output_file_72.csv
# Colonna 'monthly_mean' rimossa da output_file_73.csv
# Colonna 'monthly_mean' rimossa da output_file_74.csv
# Colonna 'monthly_mean' rimossa da output_file_75.csv
# Colonna 'monthly_mean' rimossa da output_file_76.csv
# Colonna 'monthly_mean' rimossa da output_file_77.csv
# Colonna 'monthly_mean' rimossa da output_file_78.csv
# Colonna 'monthly_mean' rimossa da output_file_79.csv
# Colonna 'monthly_mean' rimossa da output_file_8.csv
# Colonna 'monthly_mean' rimossa da output_file_80.csv
# Colonna 'monthly_mean' rimossa da output_file_81.csv
# Colonna 'monthly_mean' rimossa da output_file_82.csv
# Colonna 'monthly_mean' rimossa da output_file_83.csv
# Colonna 'monthly_mean' rimossa da output_file_84.csv
# Colonna 'monthly_mean' rimossa da output_file_85.csv
# Colonna 'monthly_mean' rimossa da output_file_86.csv
# Colonna 'monthly_mean' rimossa da output_file_87.csv
# Colonna 'monthly_mean' rimossa da output_file_88.csv
# Colonna 'monthly_mean' rimossa da output_file_89.csv
# Colonna 'monthly_mean' rimossa da output_file_9.csv
# Colonna 'monthly_mean' rimossa da output_file_90.csv
# Colonna 'monthly_mean' rimossa da output_file_91.csv
# Colonna 'monthly_mean' rimossa da output_file_92.csv
# Colonna 'monthly_mean' rimossa da output_file_93.csv
# Colonna 'monthly_mean' rimossa da output_file_94.csv
# Colonna 'monthly_mean' rimossa da output_file_95.csv
# Colonna 'monthly_mean' rimossa da output_file_96.csv
# Colonna 'monthly_mean' rimossa da output_file_97.csv
# Colonna 'monthly_mean' rimossa da output_file_98.csv
# Colonna 'monthly_mean' rimossa da output_file_99.csv

# %%
import os
import pandas as pd
import numpy as np

class ETFProcessor:
    def __init__(self, folder_path):
        self.folder_path = folder_path

    def process_file(self, file_path):
        # Read the ETF data from the CSV file into a Pandas DataFrame
        df = pd.read_csv(file_path)
        # Convert the 'Date' column to datetime format
        df['Date'] = pd.to_datetime(df['Date'])
        return df

    def save_to_csv(self, df, file_path):
        # Save the DataFrame back to the CSV file without including the index
        df.to_csv(file_path, index=False)

    def daily_return_calculation(self):
        for filename in os.listdir(self.folder_path):
            if filename.endswith(".csv"):
                file_path = os.path.join(self.folder_path, filename)
                df = self.process_file(file_path)
                # Calculate the 'daily_return' column and multiply by 100
                df['daily_return'] = (df['Adj Close'].shift(0) / df['Adj Close'].shift(1) - 1) * 100
                self.save_to_csv(df, file_path)

    def calculate_monthly_mean(self):
        for filename in os.listdir(self.folder_path):
            if filename.endswith(".csv"):
                file_path = os.path.join(self.folder_path, filename)
                df = self.process_file(file_path)
                monthly_mean = df.groupby(df['Date'].dt.to_period('M'))['daily_return'].mean()
                df['monthly_mean'] = df['Date'].dt.to_period('M').map(monthly_mean)
                self.save_to_csv(df, file_path)

    def calculate_volatility(self):
        for filename in os.listdir(self.folder_path):
            if filename.endswith(".csv"):
                file_path = os.path.join(self.folder_path, filename)
                df = self.process_file(file_path)
                monthly_group = df.groupby(df['Date'].dt.to_period("M"))
                df['volatility'] = np.nan  # Initialize the volatility column
                for month_name, month_data in monthly_group:
                    volatility_month = np.sqrt(np.mean((month_data['daily_return'] - month_data['monthly_mean'])**2))
                    percent_volatility_month = volatility_month * 100
                    df.loc[df['Date'].dt.to_period("M") == month_name, 'volatility'] = percent_volatility_month
                self.save_to_csv(df, file_path)

    def calculate_volume_monthly_mean(self):
        for filename in os.listdir(self.folder_path):
            if filename.endswith(".csv"):
                file_path = os.path.join(self.folder_path, filename)
                df = self.process_file(file_path)
                vol_monthly_mean = df.groupby(df['Date'].dt.to_period('M'))['Volume'].mean()
                df['Vol_month_mean'] = df['Date'].dt.to_period('M').map(vol_monthly_mean)
                self.save_to_csv(df, file_path)

# Example of using the ETFProcessor class
if __name__ == "__main__":
    processor = ETFProcessor('C:\\Users\\stebr\\DireDSCoding\\dscoding-projects\\stefano.bruschi\\Data\\etfs')
    processor.daily_return_calculation()
    processor.calculate_monthly_mean()
    processor.calculate_volatility()
    processor.calculate_volume_monthly_mean()

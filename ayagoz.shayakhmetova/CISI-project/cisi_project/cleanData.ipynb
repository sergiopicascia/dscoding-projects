# %% [markdown]
# <h3> Specify a directory where data modification file lies, then import dataset from csv file. </h3>

# %%
import sys
sys.path.append('/Users/apple/Documents/GitHub/dscoding-projects/ayagoz.shayakhmetova/CISI-project/')

from dataModify import CISIData

dataset = CISIData()

# %%
file_path = '/Users/apple/Documents/GitHub/dscoding-projects/ayagoz.shayakhmetova/CISI-project/cisi_project/tmdb_5000_movies.csv'
dataset.load_data_from_csv(file_path)

# %%
dataset.data_info()
# Out:
# 'Dataset information: 4803 rows loaded'

# %%
dataset.retrieve_data()
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
dataset.get_head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
dataset.get_tail()
# Out:
#       budget                                             genres  \
# 4798  220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# ...

# %% [markdown]
# <h3> Dataset modification process: cleaning columns, deletion of some columns, deletion of a rows where specified column attribute is equal to 0 or NaN. </h3>

# %%
dataset.clean_column('genres')

# %%
dataset.clean_column('keywords')

# %%
dataset.clean_column('production_companies')

# %%
dataset.drop_column('spoken_languages')
dataset.drop_column('title')

# %%
dataset.show_incorrect_rows('budget')
# Out:
#       budget                              genres  \
# 265        0               Comedy Fantasy Family
# 321        0                              Comedy
# 359        0   Adventure Animation Comedy Family
# 406        0       Drama Animation Family Comedy
# 409        0                         Drama Music
# ...      ...                                 ...
# 4795       0                               Drama
# 4797       0                    Foreign Thriller
# 4800       0        Comedy Drama Romance TVMovie
# 4801       0
# 4802       0                         Documentary
#
#                                                homepage      id  \
# 265                                                 NaN   10588
# 321                                                 NaN   77953
# 359   http://www.foxmovies.com/movies/alvin-and-the-...  258509
# 406                     http://www.arthurchristmas.com/   51052
# 409                                                 NaN   16858
# ...

# %%
dataset.remove_incorrect_rows('budget')
# Out:
#          budget                                    genres  \
# 0     237000000   Action Adventure Fantasy ScienceFiction
# 1     300000000                  Adventure Fantasy Action
# 2     245000000                    Action Adventure Crime
# 3     250000000               Action Crime Drama Thriller
# 4     260000000           Action Adventure ScienceFiction
# ...         ...                                       ...
# 4791         13                                    Horror
# 4792      20000             Crime Horror Mystery Thriller
# 4796       7000             ScienceFiction Drama Thriller
# 4798     220000                     Action Crime Thriller
# 4799       9000                            Comedy Romance
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# 1     http://disney.go.com/disneypictures/pirates/     285
# 2      http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
dataset.show_incorrect_rows('tagline')
# Out:
#          budget                                    genres  \
# 10    270000000   Adventure Fantasy Action ScienceFiction
# 56    185000000           Action Adventure ScienceFiction
# 66    175000000         Animation Comedy Family Adventure
# 78    175000000            Family Adventure Drama Fantasy
# 128   150000000                          Thriller Mystery
# ...         ...                                       ...
# 4741      75000                            ScienceFiction
# 4755      50000                               Documentary
# 4756      50000                   Horror Thriller Fantasy
# 4759      50000                               Documentary
# 4770     500000                              Drama Comedy
#
#                                              homepage      id  \
# 10                            http://www.superman.com    1452
# 56                      http://www.startrekmovie.com/  188927
# 66            http://disney.go.com/disneypictures/up/   14160
# ...

# %%
dataset.remove_incorrect_rows('tagline')
# Out:
#          budget                                    genres  \
# 0     237000000   Action Adventure Fantasy ScienceFiction
# 1     300000000                  Adventure Fantasy Action
# 2     245000000                    Action Adventure Crime
# 3     250000000               Action Crime Drama Thriller
# 4     260000000           Action Adventure ScienceFiction
# ...         ...                                       ...
# 4791         13                                    Horror
# 4792      20000             Crime Horror Mystery Thriller
# 4796       7000             ScienceFiction Drama Thriller
# 4798     220000                     Action Crime Thriller
# 4799       9000                            Comedy Romance
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# 1     http://disney.go.com/disneypictures/pirates/     285
# 2      http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
dataset.show_incorrect_rows('vote_average')
# Out:
#        budget                 genres                              homepage  \
# 3855  3500000            Documentary           http://www.timetochoose.com
# 3967        3           Drama Comedy                                   NaN
# 4486   700000                  Drama  http://naturallynative.com/home.html
# 4626   300000   Romance Comedy Drama                                   NaN
# 4638   300000     Drama Action Crime                                   NaN
#
#           id                                     keywords original_language  \
# 3855  370662                    climatechange documentary                en
# 3967   79587                                                             en
# 4486  302579   nativeamerican racism family womandirector                en
# 4626  324352                                  comingofage                en
# 4638  378237                                                             en
#
#                 original_title  \
# ...

# %%
dataset.remove_incorrect_rows('vote_average')
# Out:
#          budget                                    genres  \
# 0     237000000   Action Adventure Fantasy ScienceFiction
# 1     300000000                  Adventure Fantasy Action
# 2     245000000                    Action Adventure Crime
# 3     250000000               Action Crime Drama Thriller
# 4     260000000           Action Adventure ScienceFiction
# ...         ...                                       ...
# 4791         13                                    Horror
# 4792      20000             Crime Horror Mystery Thriller
# 4796       7000             ScienceFiction Drama Thriller
# 4798     220000                     Action Crime Thriller
# 4799       9000                            Comedy Romance
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# 1     http://disney.go.com/disneypictures/pirates/     285
# 2      http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
dataset.show_incorrect_rows('revenue')
# Out:
#          budget                                    genres  \
# 83     27000000   Action Adventure ScienceFiction Romance
# 135   150000000                     Drama Horror Thriller
# 309    84000000           Fantasy Comedy Family Adventure
# 376    90000000      ScienceFiction Action Drama Thriller
# 433    84000000              Action Comedy Crime Thriller
# ...         ...                                       ...
# 4767      50000                           Thriller Horror
# 4774      27000                             Drama Romance
# 4781      22000                            Comedy Romance
# 4791         13                                    Horror
# 4799       9000                            Comedy Romance
#
#                                     homepage      id  \
# 83                                       NaN   79698
# 135          http://www.thewolfmanmovie.com/    7978
# 309                                      NaN   10214
# ...

# %%
dataset.remove_incorrect_rows('revenue')
# Out:
#          budget                                    genres  \
# 0     237000000   Action Adventure Fantasy ScienceFiction
# 1     300000000                  Adventure Fantasy Action
# 2     245000000                    Action Adventure Crime
# 3     250000000               Action Crime Drama Thriller
# 4     260000000           Action Adventure ScienceFiction
# ...         ...                                       ...
# 4773      27000                                    Comedy
# 4788      12000                       Horror Comedy Crime
# 4792      20000             Crime Horror Mystery Thriller
# 4796       7000             ScienceFiction Drama Thriller
# 4798     220000                     Action Crime Thriller
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# 1     http://disney.go.com/disneypictures/pirates/     285
# 2      http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
dataset.duplicate_column('release_date')

# %%
dataset('release_date_duplicate')

# %%
dataset.retrieve_data()
# Out:
#          budget                                    genres  \
# 0     237000000   Action Adventure Fantasy ScienceFiction
# 1     300000000                  Adventure Fantasy Action
# 2     245000000                    Action Adventure Crime
# 3     250000000               Action Crime Drama Thriller
# 4     260000000           Action Adventure ScienceFiction
# ...         ...                                       ...
# 4773      27000                                    Comedy
# 4788      12000                       Horror Comedy Crime
# 4792      20000             Crime Horror Mystery Thriller
# 4796       7000             ScienceFiction Drama Thriller
# 4798     220000                     Action Crime Thriller
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# 1     http://disney.go.com/disneypictures/pirates/     285
# 2      http://www.sonypictures.com/movies/spectre/  206647
# ...

# %% [markdown]
# <h3> Save modified file as a new csv file. </h3>

# %%
new_dataset = dataset.new_csv('/Users/apple/Documents/GitHub/dscoding-projects/ayagoz.shayakhmetova/CISI-project/cisi_project/new_movies_1.csv')

# %% [markdown]
# <h3> Identify new dataset. </h3>

# %%
import sys
sys.path.append('/Users/apple/Documents/GitHub/dscoding-projects/ayagoz.shayakhmetova/CISI-project/')

from dataModify import CISIData

new_dataset = CISIData()

# %%
new_file_path = '/Users/apple/Documents/GitHub/dscoding-projects/ayagoz.shayakhmetova/CISI-project/cisi_project/new_movies_1.csv'
new_dataset.load_data_from_csv(new_file_path)

# %%
new_dataset.data_info()
# Out:
# 'Dataset information: 2983 rows loaded'

# %%
new_dataset.get_type()
# Out:
# budget                      int64
# genres                     object
# homepage                   object
# id                          int64
# keywords                   object
# original_language          object
# original_title             object
# overview                   object
# popularity                float64
# production_companies       object
# production_countries       object
# release_date               object
# revenue                     int64
# runtime                   float64
# status                     object
# tagline                    object
# vote_average              float64
# vote_count                  int64
# release_date_duplicate      int64
# dtype: object

# %%
new_dataset.get_head()
# Out:
#       budget                                    genres  \
# 0  237000000   Action Adventure Fantasy ScienceFiction
# 1  300000000                  Adventure Fantasy Action
# 2  245000000                    Action Adventure Crime
# 3  250000000               Action Crime Drama Thriller
# 4  260000000           Action Adventure ScienceFiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0   cultureclash future spacewar spacecolony soci...                en
# 1   ocean drugabuse exoticisland eastindiatrading...                en
# 2   spy basedonnovel secretagent sequel mi britis...                en
# ...

# %%
new_dataset.retrieve_data()
# Out:
#          budget                                    genres  \
# 0     237000000   Action Adventure Fantasy ScienceFiction
# 1     300000000                  Adventure Fantasy Action
# 2     245000000                    Action Adventure Crime
# 3     250000000               Action Crime Drama Thriller
# 4     260000000           Action Adventure ScienceFiction
# ...         ...                                       ...
# 2978      27000                                    Comedy
# 2979      12000                       Horror Comedy Crime
# 2980      20000             Crime Horror Mystery Thriller
# 2981       7000             ScienceFiction Drama Thriller
# 2982     220000                     Action Crime Thriller
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# 1     http://disney.go.com/disneypictures/pirates/     285
# 2      http://www.sonypictures.com/movies/spectre/  206647
# ...

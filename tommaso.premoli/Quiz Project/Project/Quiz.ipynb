# %% [markdown]
# ## Data Import

# %%
import pandas as pd

# %%
movies = pd.read_excel('Dataset/Movie_Dataset.xlsx')

# %%
movies
# Out:
#                                             movie_title    year  \
# 0                                                Avatar  2009.0
# 1              Pirates of the Caribbean: At World's End  2007.0
# 2                                               Spectre  2015.0
# 3                                 The Dark Knight Rises  2012.0
# 4     Star Wars: Episode VII - The Force Awakens    ...     NaN
# ...                                                 ...     ...
# 5038                            Signed Sealed Delivered  2013.0
# 5039                          The Following                 NaN
# 5040                               A Plague So Pleasant  2013.0
# 5041                                   Shanghai Calling  2012.0
# 5042                                  My Date with Drew  2004.0
#
#           director_name       actor_name                           genres  \
# 0         James Cameron      CCH Pounder  Action|Adventure|Fantasy|Sci-Fi
# 1        Gore Verbinski      Johnny Depp         Action|Adventure|Fantasy
# 2            Sam Mendes  Christoph Waltz        Action|Adventure|Thriller
# 3     Christopher Nolan        Tom Hardy                  Action|Thriller
# 4           Doug Walker      Doug Walker                      Documentary
# ...                 ...              ...                              ...
# 5038        Scott Smith      Eric Mabius                     Comedy|Drama
# 5039                NaN      Natalie Zea     Crime|Drama|Mystery|Thriller
# 5040   Benjamin Roberds      Eva Boehnke            Drama|Horror|Thriller
# 5041        Daniel Hsia        Alan Ruck             Comedy|Drama|Romance
# 5042           Jon Gunn      John August                      Documentary
#
#      country
# 0        USA
# 1        USA
# 2         UK
# 3        USA
# 4        NaN
# ...      ...
# 5038  Canada
# 5039     USA
# 5040     USA
# 5041     USA
# 5042     USA
#
# [5043 rows x 6 columns]

# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd

movies['genres'] = movies['genres'].str.lower()

def format_genres(genres):
 genres = genres.split('|')
 if len(genres) > 1:
     genres = ', '.join(genres[:-1]) + ' and ' + genres[-1]
 else:
     genres = genres[0]
 return genres

movies['genres'] = movies['genres'].apply(format_genres)

movies.dropna(inplace=True)

movies['year'] = pd.to_numeric(movies['year'], errors='coerce').fillna(0).astype(int)

# %%
movies
# Out:
#                                    movie_title  year      director_name  \
# 0                                       Avatar  2009      James Cameron
# 1     Pirates of the Caribbean: At World's End  2007     Gore Verbinski
# 2                                      Spectre  2015         Sam Mendes
# 3                        The Dark Knight Rises  2012  Christopher Nolan
# 5                                  John Carter  2012     Andrew Stanton
# ...                                        ...   ...                ...
# 5037                                 Newlyweds  2011       Edward Burns
# 5038                   Signed Sealed Delivered  2013        Scott Smith
# 5040                      A Plague So Pleasant  2013   Benjamin Roberds
# 5041                          Shanghai Calling  2012        Daniel Hsia
# 5042                         My Date with Drew  2004           Jon Gunn
#
#            actor_name                                 genres country
# 0         CCH Pounder  action, adventure, fantasy and sci-fi     USA
# 1         Johnny Depp          action, adventure and fantasy     USA
# 2     Christoph Waltz         action, adventure and thriller      UK
# 3           Tom Hardy                    action and thriller     USA
# 5        Daryl Sabara           action, adventure and sci-fi     USA
# ...               ...                                    ...     ...
# 5037      Kerry Bishé                       comedy and drama     USA
# 5038      Eric Mabius                       comedy and drama  Canada
# 5040      Eva Boehnke             drama, horror and thriller     USA
# 5041        Alan Ruck              comedy, drama and romance     USA
# 5042      John August                            documentary     USA
#
# [4927 rows x 6 columns]

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.hist(movies.year)
plt.show()

# %% [markdown]
# ## Program Creation

# %%
import pandas as pd
from numpy import random
import string
import matplotlib.pyplot as plt
import time

ID = ['A', 'B', 'C', 'D']

# Data import
movies = pd.read_excel('Dataset/Movie_Dataset.xlsx')

# Data Cleaning
movies['genres'] = movies['genres'].str.lower()


def format_genres(genres):
    genres = genres.split('|')
    if len(genres) > 1:
        genres = ', '.join(genres[:-1]) + ' and ' + genres[-1]
    else:
        genres = genres[0]
    return genres


movies['genres'] = movies['genres'].apply(format_genres)
movies.dropna(inplace=True)
movies['year'] = pd.to_numeric(movies['year'], errors='coerce').fillna(0).astype(int)

# Start of quiz creation
# Function for choosing difficulty
def choose_difficulty():
    difficulty = input("Choose your difficulty level (Easy/Difficult): ").lower()
    if difficulty == 'easy':
        return movies['year'] > 1990, 5 * 60
    elif difficulty == 'difficult':
        return movies['year'] < 1990, 3 * 60
    else:
        print("Invalid choice, defaulting to Easy")
        return movies['year'] > 1990, 5 * 60 

# Function for random question generation
def generate_question(movies, difficulty_filter):
    correct_movie = movies[difficulty_filter].sample(1)
    question = f"What is the title of the film released in {correct_movie['year'].values[0]} directed by {correct_movie['director_name'].values[0]}, starring {correct_movie['actor_name'].values[0]}, produced in {correct_movie['country'].values[0]} and belonging to the genre {correct_movie['genres'].values[0]}?"
    return question, correct_movie

# Function for generating 3 wrong answers and 1 right answer
def generate_answers(movies, correct_movie):
    incorrect_movies = movies.drop(correct_movie.index.values.tolist())
    incorrect_answers = incorrect_movies.sample(3)['movie_title'].values
    correct_answer = correct_movie['movie_title'].values[0]
    answers = [correct_answer] + list(incorrect_answers)
    random.shuffle(answers)
    return answers
# Creation of the actual quiz in which difficulty and score are taken into account for the creation of the final graph
def quiz(movies):
    difficulty_filter, time_limit = choose_difficulty()
    start_time = time.time()
    score = 0
    score_history = [0]

    for i in range(1, 11):
        elapsed_time = time.time() - start_time
        remaining_time = max(0, time_limit - elapsed_time)
        print(f"\nTime remaining: {int(remaining_time // 60)} minutes {int(remaining_time % 60)} seconds\n")

        question, correct_movie = generate_question(movies, difficulty_filter)
        answers = generate_answers(movies, correct_movie)
        print(f"Question {i}. {question}")

        for j, answer in zip(ID, answers):
            print(f"{j}. {answer}")

        user_answer = input("Your answer: ").upper()
        while user_answer not in ID:
           print("You have another chance, try again!")
           user_answer = input("Your answer: ").upper()


        correct_answer = correct_movie['movie_title'].values[0]
        selected_answer = answers[string.ascii_uppercase.index(user_answer)]
        if selected_answer == correct_answer:
            print("Correct!\n")
            score += 1
            score_history.append(score)
        else:
            print(f"Wrong! The correct answer is {correct_answer}\n")
            score_history.append(score)

        elapsed_time = time.time() - start_time
        if elapsed_time > time_limit:
            print("Time's up!")
            break

    print(f"\nYour total score is {score}/10!\n")
    plt.plot(score_history)
    plt.xlabel('Question number')
    plt.ylabel('Score')
    plt.title('Score over time')
    plt.ylim(0, 10)
    plt.show()
    retry = input("Do you want to retry? (yes/no): ").lower()
    if retry != 'no':
        quiz(movies)
    else:
        print("\nThanks for trying!")

quiz(movies)
# Out:
# Choose your difficulty level (Easy/Difficult): a
# Invalid choice, defaulting to Easy
#
# Time remaining: 4 minutes 59 seconds
#
# Question 1. What is the title of the film released in 2014 directed by Nicholas Stoller, starring Craig Roberts, produced in USA and belonging to the genre comedy?
# A. Mad Max Beyond Thunderdome
# B. Finding Neverland
# C. Neighbors
# D. Beverly Hills Cop II
# Your answer: a
# Wrong! The correct answer is Neighbors
#
#
# Time remaining: 4 minutes 58 seconds
#
# Question 2. What is the title of the film released in 1992 directed by James Foley, starring Kevin Spacey, produced in USA and belonging to the genre crime, drama and mystery?
# A. On the Outs
# B. Night of the Living Dead
# C. Glengarry Glen Ross
# D. The Wild Thornberrys Movie
# Your answer: b
# Wrong! The correct answer is Glengarry Glen Ross
#
#
# Time remaining: 4 minutes 57 seconds
#
# Question 3. What is the title of the film released in 2004 directed by Jean-Jacques Annaud, starring David Gant, produced in France and belonging to the genre adventure, drama and family?
# A. Two Brothers
# B. La Famille Bélier
# C. Must Love Dogs
# D. The Business of Strangers
# Your answer: d
# Wrong! The correct answer is Two Brothers
#
#
# Time remaining: 4 minutes 57 seconds
#
# Question 4. What is the title of the film released in 1999 directed by Andy Tennant, starring Bai Ling, produced in USA and belonging to the genre drama, history and romance?
# A. Anna and the King
# B. Buen Día, Ramón
# C. Hesher
# D. Boynton Beach Club
# Your answer: c
# Wrong! The correct answer is Anna and the King
#
#
# Time remaining: 4 minutes 56 seconds
#
# Question 5. What is the title of the film released in 2011 directed by George Miller, starring Robin Williams, produced in Australia and belonging to the genre animation, comedy, family and musical?
# A. Big Momma's House
# B. Definitely, Maybe
# C. Happy Feet 2
# D. Down and Out with the Dolls
# Your answer: a
# Wrong! The correct answer is Happy Feet 2
#
#
# Time remaining: 4 minutes 56 seconds
#
# Question 6. What is the title of the film released in 2007 directed by John Dahl, starring Philip Baker Hall, produced in USA and belonging to the genre comedy, crime, romance and thriller?
# A. Darling Lili
# B. Star Wars: Episode IV - A New Hope
# C. Paranormal Activity 2
# D. You Kill Me
# Your answer: f
# You have another chance, try again!
# Your answer: g
# You have another chance, try again!
# Your answer: g
# You have another chance, try again!
# Your answer:
# You have another chance, try again!
# Your answer: h
# You have another chance, try again!
# Your answer: h
# You have another chance, try again!
# Your answer: a
# Wrong! The correct answer is You Kill Me
#
#
# Time remaining: 4 minutes 53 seconds
#
# Question 7. What is the title of the film released in 2007 directed by Gene Teigland, starring Kendyl Joi, produced in USA and belonging to the genre mystery and thriller?
# A. Porky's
# B. Cirque du Freak: The Vampire's Assistant
# C. Arnolds Park
# D. The Good Thief
# Your answer: c
# Correct!
#
#
# Time remaining: 4 minutes 51 seconds
#
# Question 8. What is the title of the film released in 2004 directed by Léa Pool, starring William Hurt, produced in Canada and belonging to the genre adventure and drama?
# A. The Blue Butterfly
# B. Body of Lies
# C. Monster
# D. Journey 2: The Mysterious Island
# Your answer: d
# Wrong! The correct answer is The Blue Butterfly
#
#
# Time remaining: 4 minutes 51 seconds
#
# Question 9. What is the title of the film released in 2015 directed by Sam Taylor-Johnson, starring Jennifer Ehle, produced in USA and belonging to the genre drama and romance?
# A. Fifty Shades of Grey
# B. Ri¬¢hie Ri¬¢h
# C. Rubber
# D. Lakeview Terrace
# Your answer: a
# Correct!
#
#
# Time remaining: 4 minutes 51 seconds
#
# Question 10. What is the title of the film released in 2013 directed by Bill Condon, starring Benedict Cumberbatch, produced in USA and belonging to the genre biography, drama and thriller?
# A. High Road
# B. The Naked Ape
# C. The Fifth Estate
# D. Mindhunters
# Your answer: b
# Wrong! The correct answer is The Fifth Estate
#
#
# Your total score is 2/10!
# Do you want to retry? (yes/no): no
#
# Thanks for trying!

# %% [markdown]
# ## Data Import

# %%
import pandas as pd

# %%
movies = pd.read_excel('Movie_Dataset.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 movies = pd.read_excel('Movie_Dataset.xlsx')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/excel/_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/excel/_base.py:1652, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1650     ext = "xls"
#    1651 else:
# -> 1652     ext = inspect_excel_format(
#    1653         content_or_path=path_or_buffer, storage_options=storage_options
#    1654     )
#    1655     if ext is None:
#    1656         raise ValueError(
#    1657             "Excel file format cannot be determined, you must specify "
#    1658             "an engine manually."
#    1659         )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/excel/_base.py:1525, in inspect_excel_format(content_or_path, storage_options)
#    1522 if isinstance(content_or_path, bytes):
#    1523     content_or_path = BytesIO(content_or_path)
# -> 1525 with get_handle(
#    1526     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1527 ) as handle:
#    1528     stream = handle.handle
#    1529     stream.seek(0)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:865, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#    (...)
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
# --> 865         handle = open(handle, ioargs.mode)
#     866     handles.append(handle)
#     868 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Movie_Dataset.xlsx'

# %%
movies
# Out:
#                                             movie_title    year  \
# 0                                                Avatar  2009.0
# 1              Pirates of the Caribbean: At World's End  2007.0
# 2                                               Spectre  2015.0
# 3                                 The Dark Knight Rises  2012.0
# 4     Star Wars: Episode VII - The Force Awakens    ...     NaN
# ...                                                 ...     ...
# 5038                            Signed Sealed Delivered  2013.0
# 5039                          The Following                 NaN
# 5040                               A Plague So Pleasant  2013.0
# 5041                                   Shanghai Calling  2012.0
# 5042                                  My Date with Drew  2004.0
#
#           director_name       actor_name                           genres  \
# 0         James Cameron      CCH Pounder  Action|Adventure|Fantasy|Sci-Fi
# 1        Gore Verbinski      Johnny Depp         Action|Adventure|Fantasy
# 2            Sam Mendes  Christoph Waltz        Action|Adventure|Thriller
# 3     Christopher Nolan        Tom Hardy                  Action|Thriller
# 4           Doug Walker      Doug Walker                      Documentary
# ...                 ...              ...                              ...
# 5038        Scott Smith      Eric Mabius                     Comedy|Drama
# 5039                NaN      Natalie Zea     Crime|Drama|Mystery|Thriller
# 5040   Benjamin Roberds      Eva Boehnke            Drama|Horror|Thriller
# 5041        Daniel Hsia        Alan Ruck             Comedy|Drama|Romance
# 5042           Jon Gunn      John August                      Documentary
#
#      country
# 0        USA
# 1        USA
# 2         UK
# 3        USA
# 4        NaN
# ...      ...
# 5038  Canada
# 5039     USA
# 5040     USA
# 5041     USA
# 5042     USA
#
# [5043 rows x 6 columns]

# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd

movies['genres'] = movies['genres'].str.lower()

def format_genres(genres):
 genres = genres.split('|')
 if len(genres) > 1:
     genres = ', '.join(genres[:-1]) + ' and ' + genres[-1]
 else:
     genres = genres[0]
 return genres

movies['genres'] = movies['genres'].apply(format_genres)

movies.dropna(inplace=True)

movies['year'] = pd.to_numeric(movies['year'], errors='coerce').fillna(0).astype(int)

# %%
movies
# Out:
#                                    movie_title  year      director_name  \
# 0                                       Avatar  2009      James Cameron
# 1     Pirates of the Caribbean: At World's End  2007     Gore Verbinski
# 2                                      Spectre  2015         Sam Mendes
# 3                        The Dark Knight Rises  2012  Christopher Nolan
# 5                                  John Carter  2012     Andrew Stanton
# ...                                        ...   ...                ...
# 5037                                 Newlyweds  2011       Edward Burns
# 5038                   Signed Sealed Delivered  2013        Scott Smith
# 5040                      A Plague So Pleasant  2013   Benjamin Roberds
# 5041                          Shanghai Calling  2012        Daniel Hsia
# 5042                         My Date with Drew  2004           Jon Gunn
#
#            actor_name                                 genres country
# 0         CCH Pounder  action, adventure, fantasy and sci-fi     USA
# 1         Johnny Depp          action, adventure and fantasy     USA
# 2     Christoph Waltz         action, adventure and thriller      UK
# 3           Tom Hardy                    action and thriller     USA
# 5        Daryl Sabara           action, adventure and sci-fi     USA
# ...               ...                                    ...     ...
# 5037      Kerry Bishé                       comedy and drama     USA
# 5038      Eric Mabius                       comedy and drama  Canada
# 5040      Eva Boehnke             drama, horror and thriller     USA
# 5041        Alan Ruck              comedy, drama and romance     USA
# 5042      John August                            documentary     USA
#
# [4927 rows x 6 columns]

# %% [markdown]
# ## Program Creation

# %%
import pandas as pd
from numpy import random
import string
import matplotlib.pyplot as plt
import time

movies = pd.read_excel('Dataset/Movie_Dataset.xlsx')

# Data Cleaning
movies['genres'] = movies['genres'].str.lower()


def format_genres(genres):
    genres = genres.split('|')
    if len(genres) > 1:
        genres = ', '.join(genres[:-1]) + ' and ' + genres[-1]
    else:
        genres = genres[0]
    return genres


movies['genres'] = movies['genres'].apply(format_genres)
movies.dropna(inplace=True)
movies['year'] = pd.to_numeric(movies['year'], errors='coerce').fillna(0).astype(int)


def choose_difficulty():
    difficulty = input("Choose your difficulty level (Easy/Difficult): ").lower()
    if difficulty == 'easy':
        return movies['year'] > 1990, 5 * 60
    elif difficulty == 'difficult':
        return movies['year'] < 1990, 3 * 60
    else:
        print("Invalid choice, defaulting to Easy")
        return movies['year'] > 1990, 5 * 60 

def generate_question(movies, difficulty_filter):
    correct_movie = movies[difficulty_filter].sample(1)
    question = f"What is the title of the film released in {correct_movie['year'].values[0]} directed by {correct_movie['director_name'].values[0]}, starring {correct_movie['actor_name'].values[0]}, produced in {correct_movie['country'].values[0]} and belonging to the genre {correct_movie['genres'].values[0]}?"
    return question, correct_movie


def generate_answers(movies, correct_movie):
    incorrect_movies = movies.drop(correct_movie.index.values.tolist())
    incorrect_answers = incorrect_movies.sample(3)['movie_title'].values
    correct_answer = correct_movie['movie_title'].values[0]
    answers = [correct_answer] + list(incorrect_answers)
    random.shuffle(answers)
    return answers


def quiz(movies):
    difficulty_filter, time_limit = choose_difficulty()
    start_time = time.time()
    score = 0
    score_history = [0]

    for i in range(1, 11):
        elapsed_time = time.time() - start_time
        remaining_time = max(0, time_limit - elapsed_time)
        print(f"\nTime remaining: {int(remaining_time // 60)} minutes {int(remaining_time % 60)} seconds\n")

        question, correct_movie = generate_question(movies, difficulty_filter)
        answers = generate_answers(movies, correct_movie)
        print(f"Question {i}. {question}")

        for j, answer in zip(string.ascii_uppercase, answers):
            print(f"{j}. {answer}")

        user_answer = input("Your answer: ").upper()
        while user_answer not in string.ascii_uppercase:
            print("You have another chance, try again!")
            user_answer = input("Your answer: ").upper()

        correct_answer = correct_movie['movie_title'].values[0]
        selected_answer = answers[string.ascii_uppercase.index(user_answer)]
        if selected_answer == correct_answer:
            print("Correct!\n")
            score += 1
            score_history.append(score)
        else:
            print(f"Wrong! The correct answer is {correct_answer}\n")
            score_history.append(score)

        elapsed_time = time.time() - start_time
        if elapsed_time > time_limit:
            print("Time's up!")
            break

    print(f"\nYour total score is {score}/10!\n")
    plt.plot(score_history)
    plt.xlabel('Question number')
    plt.ylabel('Score')
    plt.title('Score over time')
    plt.ylim(0, 10)
    plt.show()
    retry = input("Do you want to retry? (yes/no): ").lower()
    if retry != 'no':
        quiz(movies)
    else:
        print("\nThanks for trying!")

quiz(movies)
# Out:
# Choose your difficulty level (Easy/Difficult): easy
#
# Time remaining: 4 minutes 59 seconds
#
# Question 1. What is the title of the film released in 2004 directed by Lori Silverbush, starring Judy Marte, produced in USA and belonging to the genre drama?
# A. Peggy Sue Got Married
# B. On the Outs
# C. The Beaver
# D. Incident at Loch Ness
# Your answer: c
# Wrong! The correct answer is On the Outs
#
#
# Time remaining: 4 minutes 39 seconds
#
# Question 2. What is the title of the film released in 2009 directed by Paul Weitz, starring Josh Hutcherson, produced in USA and belonging to the genre action, adventure, fantasy and thriller?
# A. Cirque du Freak: The Vampire's Assistant
# B. Boynton Beach Club
# C. Coach Carter
# D. Toy Story 3
# Your answer: a
# Correct!
#
#
# Time remaining: 4 minutes 19 seconds
#
# Question 3. What is the title of the film released in 2013 directed by Raja Gosnell, starring Jacob Tremblay, produced in USA and belonging to the genre adventure, animation, comedy, family and fantasy?
# A. Train
# B. Pandora's Box
# C. The Smurfs 2
# D. Ramona and Beezus
# Your answer: b
# Wrong! The correct answer is The Smurfs 2
#
#
# Time remaining: 3 minutes 59 seconds
#
# Question 4. What is the title of the film released in 2003 directed by Sue Corcoran, starring Tony Doupe, produced in USA and belonging to the genre comedy, fantasy, horror and musical?
# A. Madea's Family Reunion
# B. Michael Jordan to the Max
# C. Blue Valentine
# D. Gory Gory Hallelujah
# Your answer: d
# Correct!
#
#
# Time remaining: 3 minutes 39 seconds
#
# Question 5. What is the title of the film released in 2015 directed by Brad Bird, starring Judy Greer, produced in USA and belonging to the genre action, adventure, family, mystery and sci-fi?
# A. Tomorrowland
# B. The Hunt for Red October
# C. Sinister
# D. Treading Water
# Your answer: a
# Correct!
#
#
# Time remaining: 3 minutes 25 seconds
#
# Question 6. What is the title of the film released in 2007 directed by Craig Gillespie, starring Ryan Gosling, produced in USA and belonging to the genre comedy, drama and romance?
# A. White Oleander
# B. Bullets Over Broadway
# C. Lars and the Real Girl
# D. Hot Tub Time Machine
# Your answer: c
# Correct!
#
#
# Time remaining: 3 minutes 4 seconds
#
# Question 7. What is the title of the film released in 2011 directed by James Bobin, starring Bill Cobbs, produced in USA and belonging to the genre adventure, comedy, family and musical?
# A. The Muppets
# B. Total Recall
# C. Shalako
# D. Beauty Shop
# Your answer: c
# Wrong! The correct answer is The Muppets
#
#
# Time remaining: 2 minutes 50 seconds
#
# Question 8. What is the title of the film released in 2007 directed by Adrienne Shelly, starring Lew Temple, produced in USA and belonging to the genre comedy, drama and romance?
# A. The Prince
# B. Waitress
# C. Ouija
# D. Fame
# Your answer: a
# Wrong! The correct answer is Waitress
#
#
# Time remaining: 2 minutes 32 seconds
#
# Question 9. What is the title of the film released in 2015 directed by Wilson Yip, starring Mike Tyson, produced in Hong Kong and belonging to the genre action, biography, drama and history?
# A. Rocket Singh: Salesman of the Year
# B. Ip Man 3
# C. The Forsaken
# D. Star Wars: Episode V - The Empire Strikes Back
# Your answer: c
# Wrong! The correct answer is Ip Man 3
#
#
# Time remaining: 2 minutes 3 seconds
#
# Question 10. What is the title of the film released in 1991 directed by Barbra Streisand, starring George Carlin, produced in USA and belonging to the genre drama and romance?
# A. The Waterboy
# B. The Prince of Tides
# C. The Claim
# D. The Losers
# Your answer: d
# Wrong! The correct answer is The Prince of Tides
#
#
# Your total score is 4/10!
# Do you want to retry? (yes/no): yes
# Choose your difficulty level (Easy/Difficult): difficult
#
# Time remaining: 2 minutes 59 seconds
#
# Question 1. What is the title of the film released in 1936 directed by Michael Curtiz, starring Errol Flynn, produced in USA and belonging to the genre action, adventure, romance and war?
# A. My Bloody Valentine
# B. The Cotton Club
# C. Office Space
# D. The Charge of the Light Brigade
# Your answer: d
# Correct!
#
#
# Time remaining: 2 minutes 45 seconds
#
# Question 2. What is the title of the film released in 1989 directed by Mary Lambert, starring Miko Hughes, produced in USA and belonging to the genre fantasy and horror?
# A. Ironclad
# B. Pet Sematary
# C. My Beautiful Laundrette
# D. The Salon
# Your answer: a
# Wrong! The correct answer is Pet Sematary
#
#
# Time remaining: 2 minutes 31 seconds
#
# Question 3. What is the title of the film released in 1964 directed by John Frankenheimer, starring Jeanne Moreau, produced in France and belonging to the genre thriller and war?
# A. Echo Dr.
# B. The Train
# C. Drive Me Crazy
# D. Young Frankenstein
# Your answer: a
# Wrong! The correct answer is The Train
#
#
# Time remaining: 2 minutes 10 seconds
#
# Question 4. What is the title of the film released in 1965 directed by David Lean, starring Julie Christie, produced in USA and belonging to the genre drama, romance and war?
# A. Me and You and Everyone We Know
# B. Doctor Zhivago
# C. Dogma
# D. Poetic Justice
# Your answer: d
# Wrong! The correct answer is Doctor Zhivago
#
#
# Time remaining: 1 minutes 49 seconds
#
# Question 5. What is the title of the film released in 1953 directed by Eugène Lourié, starring Kenneth Tobey, produced in USA and belonging to the genre adventure, horror and sci-fi?
# A. One Night with the King
# B. Divergent
# C. The Beast from 20,000 Fathoms
# D. The Best Man Holiday
# Your answer: c
# Correct!
#
#
# Time remaining: 1 minutes 9 seconds
#
# Question 6. What is the title of the film released in 1988 directed by Richard Donner, starring Bill Murray, produced in USA and belonging to the genre comedy, drama and fantasy?
# A. Scrooged
# B. Live and Let Die
# C. Panic Room
# D. Jackass 3D
# Your answer: a
# Correct!
#
#
# Time remaining: 0 minutes 46 seconds
#
# Question 7. What is the title of the film released in 1984 directed by Wolfgang Petersen, starring Gerald McRaney, produced in West Germany and belonging to the genre adventure, drama, family and fantasy?
# A. Lord of War
# B. City of Ghosts
# C. The NeverEnding Story
# D. Once Upon a Time in America
# Your answer: c
# Correct!
#
#
# Time remaining: 0 minutes 19 seconds
#
# Question 8. What is the title of the film released in 1940 directed by Alfred Hitchcock, starring Laurence Olivier, produced in USA and belonging to the genre drama, film-noir, mystery and thriller?
# A. Little Women
# B. Rebecca
# C. The Jungle Book 2
# D. True Romance
# Your answer: d
# Wrong! The correct answer is Rebecca
#
# Time's up!
#
# Your total score is 4/10!
# Do you want to retry? (yes/no): no
#
# Thanks for trying!

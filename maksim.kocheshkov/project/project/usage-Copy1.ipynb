# %%
import pandas as pd

# %% [markdown]
# Importing data

# %%
data = pd.read_csv('/Users/zwouq/Downloads/archive 2/GlobalLandTemperaturesByMajorCity.csv')

# %% [raw]
# # Descriptive statistics

# %%
data
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1849-01-01              26.704                          1.435
# 1       1849-02-01              27.434                          1.362
# 2       1849-03-01              28.101                          1.612
# 3       1849-04-01              26.140                          1.387
# 4       1849-05-01              25.427                          1.200
# ...            ...                 ...                            ...
# 239172  2013-05-01              18.979                          0.807
# 239173  2013-06-01              23.522                          0.647
# 239174  2013-07-01              25.251                          1.042
# 239175  2013-08-01              24.528                          0.840
# 239176  2013-09-01                 NaN                            NaN
#
#            City        Country Latitude Longitude
# 0       Abidjan  Côte D'Ivoire    5.63N     3.23W
# ...

# %% [markdown]
# Mean temperature by city and country

# %%
grouping_result = data.groupby(["Country", "City"])["AverageTemperature"].mean()
grouping_result.head(30)
# Out:
# Country      City
# Afghanistan  Kabul             14.342919
# Angola       Luanda            23.693046
# Australia    Melbourne         13.374304
#              Sydney            17.002299
# Bangladesh   Dhaka             25.490568
# Brazil       Belo Horizonte    21.071396
#              Brasília          21.727595
#              Fortaleza         27.008640
#              Rio De Janeiro    23.788916
#              Salvador          24.656971
#              São Paulo         19.699368
# Burma        Rangoon           26.735193
# Canada       Montreal           4.445014
#              Toronto            5.773911
# Chile        Santiago           5.692277
# China        Changchun          4.923798
#              Chengdu           10.638042
#              Chongqing         16.844962
#              Dalian            10.229077
#              Guangzhou         21.608684
#              Harbin             3.625744
#              Jinan             13.089814
# ...

# %%
cities_wo_dupl = data.drop_duplicates(subset=["Latitude", "Longitude"])
country_grouping = cities_wo_dupl["Country"].value_counts()
print(country_grouping)
# Out:
# China                                 15
# India                                 12
# Brazil                                 6
# Nigeria                                3
# Turkey                                 3
# United States                          3
# Canada                                 2
# South Africa                           2
# Indonesia                              2
# Saudi Arabia                           2
# Russia                                 2
# Pakistan                               2
# Colombia                               2
# Japan                                  2
# Egypt                                  2
# Australia                              2
# Somalia                                1
# Mexico                                 1
# Côte D'Ivoire                          1
# Italy                                  1
# Kenya                                  1
# France                                 1
# Burma                                  1
# ...
